# %%
# Imports
import numpy as np
import pandas as pd
import os 
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import folium
import json
import collections
from collections import Counter

from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import ExtraTreesClassifier

# %% [markdown]
# Read file for Arnesh

# %%
listings_filepath = '/Users/arneshsaha/Desktop/AirBnb/datasets/listings.csv'
listings_df = pd.read_csv(listings_filepath)

# %% [markdown]
# Read file for Abhay

# %%
# listings_filepath = '/Users/abhayrakeshdeshmukhmaurya/Library/CloudStorage/OneDrive-UniversityofEdinburgh/CS/University/Year 2/Data Science/CW3/AirBnb/datasets/listings.csv'
# listings_df = pd.read_csv(listings_filepath)

# %% [markdown]
# Data Cleaning

# %%
# Deleting Unnecessary Columns
columns = ['host_url', 'host_name', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'calendar_updated', 'calendar_last_scraped','picture_url', 'neighbourhood_group_cleansed','license', 'host_location', 'first_review', 'last_review', 'host_thumbnail_url', 'host_picture_url' ]
listings_df.drop(columns=columns, inplace=True)

# Converting columns with (True, False) to (1, 0)
replace_dict = {'instant_bookable':{'t':1, 'f':0}, 
                'host_identity_verified':{'t':1, 'f':0},
                'host_has_profile_pic':{'t':1, 'f':0},
                'host_is_superhost':{'t':1, 'f':0},
                'has_availability':{'t':1, 'f':0}
                }
listings_df = listings_df.replace(replace_dict)

# Removing HTML tags from description
def remove_html_tags(text):
    if pd.isna(text):
        return text
    soup = BeautifulSoup(text, 'html.parser')
    return soup.get_text()

listings_df['description'] = listings_df['description'].apply(remove_html_tags)

# Creating parking column and assigning the rows with parking feature
parking_rows = listings_df[(listings_df['name'].str.contains('parking', case=False)) | 
                           (listings_df['amenities'].apply(lambda x: 'parking' in x))]

listings_df['Parking'] = 0
listings_df.loc[parking_rows.index, 'Parking'] = 1

# Creating room_type_num column to store unique types in room_type
room_type_labels, room_type_unique = pd.factorize(listings_df['room_type'])
listings_df['room_type_num'] = room_type_labels
# ['Entire home/apt', 'Private room', 'Shared room', 'Hotel room']

# Removing % symbol 
listings_df['host_acceptance_rate'] = listings_df['host_acceptance_rate'].str.replace('%', '')
listings_df['host_response_rate'] = listings_df['host_response_rate'].str.replace('%', '')


listings_df.head()
# Out:
# /var/folders/rv/l0bvb2qx7kj9z133h3zxt1040000gn/T/ipykernel_16856/3872489768.py:18: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, 'html.parser')
#          id                                               name  \
# 0   15420.0                  Georgian Boutique Apt City Centre
# 1  707097.0  Centre Royal Mile Apartment 3 bedrooms 2 bathr...
# 2  728199.0   Private room in central, spacious and comfy flat
# 3  732008.0                          51 18 Caledonian Crescent
# 4  744710.0  Refurbished Flat in a Georgian Era Building in...
#
#                                          description  \
# 0  Stunning, spacious ground floor apartment minu...
# 1                                                NaN
# 2  Fantastic main door flat over two levels withi...
# 3  This beautiful third floor apartment is set in...
# 4  A stunning apartment in the heart of Edinburgh...
#
#                                neighborhood_overview  host_id  host_since  \
# 0  The neighbourhood is in the historic New Town,...    60423  06/12/2009
# 1  The location is the perfect for tourism , shor...  3092851  29/07/2012
# 2  Great location for access to the city centre, ...  3776412  06/10/2012
# 3                                                NaN  3810279  09/10/2012
# 4  The apartment is in a Central Edinburgh neighb...  3737047  02/10/2012
#
#                                           host_about  host_response_time  \
# 0  I have a background in property, having worked...  within a few hours
# 1  Airbnb partner owner . Will do my best to make...        within a day
# 2  We are an early/mid 40's couple who love to tr...      within an hour
# 3  We are a family run business specialising in h...      within an hour
# 4  I'm Gareth and I own and manage this gem of a ...      within an hour
#
#   host_response_rate host_acceptance_rate  ...  review_scores_location  \
# 0                100                   96  ...                    4.98
# 1                 50                   84  ...                    4.94
# 2                100                   95  ...                    4.73
# 3                100                   99  ...                    4.71
# 4                100                  100  ...                    4.96
#
#   review_scores_value  instant_bookable  calculated_host_listings_count  \
# 0                4.91                 0                               1
# 1                4.09                 1                               8
# 2                4.79                 0                               1
# 3                4.70                 1                               2
# 4                4.86                 1                               1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           6
# 2                                           0
# 3                                           2
# 4                                           1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             2
# 2                                             1
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms reviews_per_month Parking  \
# 0                                            0              3.10       1
# 1                                            0              0.55       1
# 2                                            0              2.86       1
# 3                                            0              2.27       1
# 4                                            0              1.73       1
#
#    room_type_num
# 0              0
# 1              0
# 2              1
# 3              0
# 4              0
#
# [5 rows x 61 columns]

# %% [markdown]
# Abhay GeoJson File Path

# %%
# path = '/Users/abhayrakeshdeshmukhmaurya/Library/CloudStorage/OneDrive-UniversityofEdinburgh/CS/University/Year 2/Data Science/CW3/AirBnb/datasets/neighbourhoods.geojson'

# %% [markdown]
# Arnesh GeoJSon File PAth

# %%
path = '/Users/arneshsaha/Desktop/AirBnb/datasets/neighbourhoods.geojson'

# %%
# # read the .geojson file
# with open(path) as f:
#     data = json.load(f)

# # create a folium map centered at a specific location
# m = folium.Map(location=[55.9533, -3.1883], zoom_start=12)

# folium.GeoJson(
#     'https://raw.githubusercontent.com/johan/world.geo.json/master/countries/GBR.geo.json',
#     name='geojson'
# ).add_to(m)

# # add the data to the map as a GeoJSON layer
# folium.GeoJson(data).add_to(m)

# sample_df = listings_df.sample(n=50, random_state=42)
# # Add markers for each point in the sampled DataFrame
# for index, row in sample_df.iterrows():
#     folium.Marker([row['latitude'], row['longitude']]).add_to(m)

# # display the map in the Jupyter notebook
# m

# %% [markdown]
# Question 1

# %%
# Deleting columns unnecessary for question1-
quality_df = listings_df
columns =['description', 'neighborhood_overview', 'host_since', 'host_about', 'host_neighbourhood', 'host_verifications', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'property_type', 'reviews_per_month']
quality_df.drop(columns=columns, inplace=True)
quality_df.dropna(subset=['host_response_time', 'bedrooms','review_scores_cleanliness', "beds","host_acceptance_rate", "bathrooms_text"], inplace=True)

# Convert variables from host_response_time to int into host_response_time_num column
host_response_time_labels, host_response_time_unique = pd.factorize(quality_df['host_response_time'])
quality_df['host_response_time_num'] = host_response_time_labels
# ['within a few hours', 'within a day', 'within an hour', 'a few days or more']

quality_df['host_response_rate'] = quality_df['host_response_rate'].astype(float)
quality_df['host_acceptance_rate'] = quality_df['host_acceptance_rate'].astype(float)

# Removing dollar sign from price
quality_df['price'] = quality_df['price'].str.replace(',', '',regex=True).str.replace('$', '',regex=True).astype('float')

# Extract the number from each entry in the 'bathrooms_text' column
quality_df['bathrooms_text'].fillna('0 baths', inplace=True)
quality_df['bathrooms'] = quality_df['bathrooms_text'].apply(lambda x: pd.to_numeric(pd.Series([x]).str.extract(r'(\d+\.?\d*)')[0], errors='coerce').fillna(0).astype('Float64'))
# Dropping 'bathrooms_text"
quality_df.drop(columns=['bathrooms_text'], inplace=True)

# Removing any row with Bathrooms = 0
quality_df = quality_df.drop(quality_df[quality_df['bathrooms'] == 0].index)

quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5241 entries, 0 to 7387
# Data columns (total 49 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5241 non-null   float64
#  1   name                                          5241 non-null   object
#  2   host_id                                       5241 non-null   int64
#  3   host_response_time                            5241 non-null   object
#  4   host_response_rate                            5241 non-null   float64
#  5   host_acceptance_rate                          5241 non-null   float64
#  6   host_is_superhost                             5241 non-null   float64
#  7   host_listings_count                           5241 non-null   int64
#  8   host_total_listings_count                     5241 non-null   int64
#  9   host_has_profile_pic                          5241 non-null   int64
#  10  host_identity_verified                        5241 non-null   int64
#  11  neighbourhood_cleansed                        5241 non-null   object
#  12  accommodates                                  5241 non-null   int64
#  13  bathrooms                                     5241 non-null   float64
#  14  bedrooms                                      5241 non-null   float64
#  15  beds                                          5241 non-null   float64
#  16  amenities                                     5241 non-null   object
#  17  price                                         5241 non-null   float64
#  18  minimum_nights                                5241 non-null   int64
#  19  maximum_nights                                5241 non-null   int64
#  20  minimum_minimum_nights                        5241 non-null   int64
#  21  maximum_minimum_nights                        5241 non-null   int64
#  22  minimum_maximum_nights                        5241 non-null   int64
#  23  maximum_maximum_nights                        5241 non-null   int64
#  24  minimum_nights_avg_ntm                        5241 non-null   float64
#  25  maximum_nights_avg_ntm                        5241 non-null   float64
#  26  has_availability                              5241 non-null   int64
#  27  availability_30                               5241 non-null   int64
#  28  availability_60                               5241 non-null   int64
#  29  availability_90                               5241 non-null   int64
#  30  availability_365                              5241 non-null   int64
#  31  number_of_reviews                             5241 non-null   int64
#  32  number_of_reviews_ltm                         5241 non-null   int64
#  33  number_of_reviews_l30d                        5241 non-null   int64
#  34  review_scores_rating                          5241 non-null   float64
#  35  review_scores_accuracy                        5241 non-null   float64
#  36  review_scores_cleanliness                     5241 non-null   float64
#  37  review_scores_checkin                         5241 non-null   float64
#  38  review_scores_communication                   5241 non-null   float64
#  39  review_scores_location                        5241 non-null   float64
#  40  review_scores_value                           5241 non-null   float64
#  41  instant_bookable                              5241 non-null   int64
#  42  calculated_host_listings_count                5241 non-null   int64
#  43  calculated_host_listings_count_entire_homes   5241 non-null   int64
#  44  calculated_host_listings_count_private_rooms  5241 non-null   int64
#  45  calculated_host_listings_count_shared_rooms   5241 non-null   int64
#  46  Parking                                       5241 non-null   int64
#  47  room_type_num                                 5241 non-null   int64
#  48  host_response_time_num                        5241 non-null   int64
# dtypes: float64(17), int64(28), object(4)
# memory usage: 2.0+ MB

# %% [markdown]
# Extracting amenities

# %%
def extract_words(x):
    x = x.strip('[]')
    x = x.replace('"', '')
    return x.split(', ')
quality_df['amenities'] = quality_df['amenities'].apply(extract_words)

# %%
import re
def extract_strings(row):
    strings = []
    for item in row['amenities']:
        string = re.sub(r'[^\w\s]', '', item)  # remove special characters
        strings.append(string.lower())  # convert to lowercase and append to the list
    return strings

# apply the function to the DataFrame and store the result in a new column
quality_df['amenities'] = quality_df.apply(lambda row: extract_strings(row), axis=1)

# print the updated DataFrame

quality_df['amenities'].shape
# Out:
# (5241,)

# %%
amenities_array = quality_df['amenities'].to_list()
flattened_amenities_array = [element for sublist in amenities_array for element in sublist]
counter = Counter(flattened_amenities_array)
counter.most_common()
# Out:
# [('smoke alarm', 5080),
#  ('essentials', 4798),
#  ('kitchen', 4633),
#  ('wifi', 4579),
#  ('hair dryer', 4560),
#  ('carbon monoxide alarm', 4514),
#  ('iron', 4440),
#  ('long term stays allowed', 4361),
#  ('hangers', 4305),
#  ('hot water', 4272),
#  ('dishes and silverware', 4090),
#  ('refrigerator', 3966),
#  ('cooking basics', 3819),
#  ('bed linens', 3811),
#  ('heating', 3506),
#  ('microwave', 3420),
#  ('shampoo', 3390),
#  ('oven', 3068),
#  ('washer', 3023),
#  ('self checkin', 2737),
#  ('tv', 2634),
#  ('fire extinguisher', 2534),
#  ('hot water kettle', 2406),
#  ('lockbox', 2361),
#  ('first aid kit', 2299),
#  ('stove', 2149),
#  ('toaster', 2105),
#  ('dishwasher', 2104),
#  ('cleaning products', 2052),
#  ('freezer', 1934),
#  ('bathtub', 1871),
#  ('shower gel', 1870),
#  ('wine glasses', 1858),
#  ('dedicated workspace', 1849),
#  ('dining table', 1781),
#  ('extra pillows and blankets', 1748),
#  ('free parking on premises', 1666),
#  ('drying rack for clothing', 1627),
#  ('free street parking', 1574),
#  ('coffee maker', 1513),
#  ('roomdarkening shades', 1480),
#  ('private entrance', 1329),
#  ('coffee', 1327),
#  ('central heating', 1318),
#  ('body soap', 1313),
#  ('luggage dropoff allowed', 1237),
#  ('free washer u2013 in unit', 1132),
#  ('books and reading material', 1081),
#  ('dryer', 1054),
#  ('conditioner', 945),
#  ('host greets you', 929),
#  ('single level home', 856),
#  ('paid parking off premises', 815),
#  ('baking sheet', 797),
#  ('pack u2019n playtravel crib', 776),
#  ('pets allowed', 726),
#  ('laundromat nearby', 693),
#  ('high chair', 663),
#  ('indoor fireplace', 653),
#  ('ethernet connection', 632),
#  ('backyard', 623),
#  ('clothing storage closet', 592),
#  ('crib', 564),
#  ('outdoor furniture', 520),
#  ('elevator', 496),
#  ('board games', 471),
#  ('lock on bedroom door', 450),
#  ('paid street parking off premises', 449),
#  ('garden view', 445),
#  ('clothing storage', 438),
#  ('private patio or balcony', 437),
#  ('tv with standard cable', 424),
#  ('city skyline view', 424),
#  ('free dryer u2013 in unit', 423),
#  ('outdoor dining area', 402),
#  ('breakfast', 390),
#  ('netflix', 389),
#  ('blender', 370),
#  ('stainless steel oven', 367),
#  ('childrenu2019s books and toys', 359),
#  ('security cameras on property', 345),
#  ('clothing storage dresser and closet', 341),
#  ('private backyard u2013 fully fenced', 326),
#  ('clothing storage closet and dresser', 323),
#  ('coffee maker french press', 303),
#  ('paid parking on premises', 290),
#  ('shared backyard u2013 fully fenced', 273),
#  ('childrenu2019s dinnerware', 271),
#  ('portable fans', 259),
#  ('mini fridge', 246),
#  ('patio or balcony', 235),
#  ('standard cable', 190),
#  ('coffee maker nespresso', 188),
#  ('bbq grill', 173),
#  ('gas stove', 164),
#  ('cleaning available during stay', 163),
#  ('free washer u2013 in building', 157),
#  ('mountain view', 156),
#  ('clothing storage dresser', 155),
#  ('park view', 153),
#  ('courtyard view', 150),
#  ('pack u2019n playtravel crib  available upon request', 149),
#  ('waterfront', 146),
#  ('keypad', 140),
#  ('electric stove', 135),
#  ('public or shared beach access', 133),
#  ('coffee maker espresso machine', 132),
#  ('smart lock', 132),
#  ('clothing storage wardrobe', 124),
#  ('private living room', 116),
#  ('barbecue utensils', 109),
#  ('induction stove', 108),
#  ('radiant heating', 106),
#  ('safe', 104),
#  ('window guards', 103),
#  ('disney', 103),
#  ('premium cable', 101),
#  ('shared patio or balcony', 101),
#  ('amazon prime video', 101),
#  ('bathroom essentials', 99),
#  ('bedroom comforts', 99),
#  ('hdtv with netflix', 99),
#  ('rice maker', 98),
#  ('indoor fireplace gas', 97),
#  ('piano', 97),
#  ('babysitter recommendations', 96),
#  ('hdtv', 94),
#  ('portable heater', 94),
#  ('sound system', 92),
#  ('coffee maker drip coffee maker', 92),
#  ('indoor fireplace electric', 87),
#  ('fire pit', 85),
#  ('air conditioning', 81),
#  ('smoking allowed', 79),
#  ('shared backyard u2013 not fully fenced', 78),
#  ('hdtv with amazon prime video', 77),
#  ('baby bath', 77),
#  ('stainless steel gas stove', 74),
#  ('sea view', 73),
#  ('indoor fireplace woodburning', 73),
#  ('paid parking garage off premises', 73),
#  ('dresser', 73),
#  ('full kitchen', 72),
#  ('exercise equipment', 71),
#  ('fire tv', 70),
#  ('pocket wifi', 67),
#  ('record player', 66),
#  ('shared backyard', 65),
#  ('outlet covers', 64),
#  ('pack u2019n playtravel crib  always at the listing', 64),
#  ('free dryer u2013 in building', 62),
#  ('game console', 61),
#  ('lake access', 60),
#  ('ev charger', 59),
#  ('fireplace guards', 57),
#  ('crib  available upon request', 57),
#  ('closet', 57),
#  ('and wardrobe', 56),
#  ('apple tv', 55),
#  ('paid parking lot off premises', 55),
#  ('bluetooth sound system', 54),
#  ('free washer', 54),
#  ('french press', 53),
#  ('coffee maker pourover coffee', 50),
#  ('nespresso', 50),
#  ('and dresser', 48),
#  ('chromecast', 48),
#  ('hdtv with standard cable', 45),
#  ('gym', 44),
#  ('wardrobe', 44),
#  ('and closet', 44),
#  ('beach access', 42),
#  ('private backyard', 42),
#  ('clothing storage walkin closet', 42),
#  ('river view', 42),
#  ('dvd player', 41),
#  ('changing table', 40),
#  ('childrenu2019s books and toys for ages 02 years old', 39),
#  ('exercise equipment free weights', 39),
#  ('tv with netflix', 39),
#  ('baby safety gates', 38),
#  ('free dryer', 38),
#  ('private backyard u2013 not fully fenced', 38),
#  ('stainless steel stove', 37),
#  ('bread maker', 36),
#  ('building staff', 36),
#  ('beach view', 35),
#  ('trash compactor', 34),
#  ('canal view', 33),
#  ('tv with amazon prime video', 33),
#  ('bidet', 33),
#  ('shared gym nearby', 33),
#  ('harbor view', 32),
#  ('paid washer u2013 in unit', 32),
#  ('bbq grill charcoal', 32),
#  ('paid pack u2019n playtravel crib  available upon request', 32),
#  ('roku', 31),
#  ('childrenu2019s books and toys for ages 02 years old and 25 years old', 31),
#  ('bikes', 30),
#  ('yoga mat', 30),
#  ('pourover coffee', 28),
#  ('bay view', 28),
#  ('paid washer u2013 in building', 28),
#  ('25 years old', 27),
#  ('beach access u2013 beachfront', 27),
#  ('ocean view', 26),
#  ('42 hdtv with amazon prime video', 25),
#  ('resort access', 24),
#  ('stainless steel electric stove', 23),
#  ('game console ps4', 23),
#  ('55 hdtv with amazon prime video', 23),
#  ('standalone high chair  always at the listing', 23),
#  ('42 hdtv with netflix', 22),
#  ('free driveway parking on premises', 22),
#  ('sonos bluetooth sound system', 21),
#  ('sound system with bluetooth and aux', 21),
#  ('exercise equipment yoga mat', 21),
#  ('43 hdtv with amazon prime video', 21),
#  ('folding or convertible high chair  available upon request', 21),
#  ('free parking on premises u2013 1 space', 20),
#  ('43 hdtv', 20),
#  ('and walkin closet', 20),
#  ('clothing storage wardrobe and closet', 20),
#  ('washer u2013u00a0in unit', 20),
#  ('510 years old', 19),
#  ('and 10 years old', 19),
#  ('ceiling fan', 19),
#  ('table corner guards', 19),
#  ('hammock', 19),
#  ('baby monitor', 18),
#  ('crib  always at the listing', 18),
#  ('50 hdtv with netflix', 18),
#  ('free residential garage on premises u2013 1 space', 17),
#  ('sonos sound system', 17),
#  ('dove body soap', 17),
#  ('55 hdtv with netflix', 17),
#  ('32 hdtv with amazon prime video', 16),
#  ('paid parking lot on premises', 16),
#  ('free driveway parking on premises u2013 1 space', 16),
#  ('valley view', 16),
#  ('private hot tub', 16),
#  ('wifi u2013 36 mbps', 16),
#  ('50 hdtv with amazon prime video', 16),
#  ('43 hdtv with netflix', 16),
#  ('paid dryer u2013 in building', 16),
#  ('walkin closet', 16),
#  ('32 hdtv with standard cable', 15),
#  ('bosch stainless steel oven', 15),
#  ('fast wifi u2013 73 mbps', 15),
#  ('fast wifi u2013 111 mbps', 15),
#  ('standalone high chair  available upon request', 15),
#  ('40 hdtv with netflix', 14),
#  ('42 hdtv', 14),
#  ('paid high chair  available upon request', 14),
#  ('clothing storage walkin closet and dresser', 14),
#  ('wifi u2013 35 mbps', 14),
#  ('40 hdtv with amazon prime video', 14),
#  ('game console xbox one', 14),
#  ('paid crib  available upon request', 14),
#  ('sound system with aux', 13),
#  ('paid dryer u2013 in unit', 13),
#  ('32 hdtv with netflix', 13),
#  ('portable air conditioning', 13),
#  ('hdtv with premium cable', 13),
#  ('scottish fine soaps body soap', 13),
#  ('clothing storage closet and wardrobe', 13),
#  ('fast wifi u2013 110 mbps', 12),
#  ('clothing storage wardrobe and dresser', 12),
#  ('scottish fine soaps shampoo', 12),
#  ('65 hdtv with amazon prime video', 12),
#  ('samsung refrigerator', 12),
#  ('40 hdtv with standard cable', 11),
#  ('high chair  available upon request', 11),
#  ('fast wifi u2013 75 mbps', 11),
#  ('hdtv with fire tv', 11),
#  ('clothing storage dresser and walkin closet', 11),
#  ('and 510 years old', 11),
#  ('free residential garage on premises', 11),
#  ('outdoor shower', 11),
#  ('beach essentials', 11),
#  ('hotpoint refrigerator', 11),
#  ('40 hdtv', 10),
#  ('smeg refrigerator', 10),
#  ('exercise equipment stationary bike', 10),
#  ('tv with premium cable', 10),
#  ('free carport on premises u2013 1 space', 10),
#  ('fast wifi u2013 109 mbps', 10),
#  ('clothing storage dresser and wardrobe', 10),
#  ('40 hdtv with fire tv', 10),
#  ('public or shared beach access u2013 beachfront', 10),
#  ('beko refrigerator', 10),
#  ('hbo max', 10),
#  ('standalone high chair', 10),
#  ('various body soap', 9),
#  ('bosch oven', 9),
#  ('wifi u2013 16 mbps', 9),
#  ('32 hdtv', 9),
#  ('hot tub', 9),
#  ('backyard  fully fenced', 9),
#  ('fast wifi u2013 107 mbps', 9),
#  ('bbq grill gas', 9),
#  ('pool table', 9),
#  ('marina view', 9),
#  ('stainless steel induction stove', 9),
#  ('32 tv', 9),
#  ('hdtv with chromecast', 9),
#  ('55 hdtv', 9),
#  ('neff stainless steel oven', 9),
#  ('fast wifi u2013 112 mbps', 9),
#  ('32 hdtv with chromecast', 9),
#  ('espresso machine', 9),
#  ('lamona stainless steel electric stove', 9),
#  ('pool', 8),
#  ('paid parking lot on premises u2013 1 space', 8),
#  ('hdtv with disney', 8),
#  ('alexa bluetooth sound system', 8),
#  ('wifi u2013 38 mbps', 8),
#  ('fast wifi u2013 105 mbps', 8),
#  ('fast wifi u2013 52 mbps', 8),
#  ('free carport on premises', 8),
#  ('central air conditioning', 8),
#  ('fast wifi u2013 108 mbps', 8),
#  ('clothing storage walkin closet and closet', 8),
#  ('50 hdtv', 8),
#  ('radox body soap', 8),
#  ('wifi u2013 15 mbps', 8),
#  ('game console nintendo wii', 8),
#  ('42 hdtv with fire tv', 8),
#  ('fast wifi u2013 67 mbps', 8),
#  ('siemens induction stove', 8),
#  ('bosch refrigerator', 8),
#  ('siemens refrigerator', 8),
#  ('42 hdtv with standard cable', 7),
#  ('fast wifi u2013 70 mbps', 7),
#  ('shared sauna', 7),
#  ('fast wifi u2013 64 mbps', 7),
#  ('mosquito net', 7),
#  ('fast wifi u2013 145 mbps', 7),
#  ('gym nearby', 7),
#  ('faith in nature conditioner', 7),
#  ('40 tv with standard cable', 7),
#  ('childrenu2019s books and toys for ages 510 years old', 7),
#  ('game console ps3', 7),
#  ('clothing storage closet and walkin closet', 7),
#  ('fast wifi u2013 71 mbps', 7),
#  ('free driveway parking on premises u2013 2 spaces', 7),
#  ('shared gym in building', 7),
#  ('folding or convertible high chair  always at the listing', 7),
#  ('shared hot tub', 7),
#  ('hdtv with apple tv', 7),
#  ('golf course view', 7),
#  ('paid resort access', 7),
#  ('55 hdtv with premium cable', 7),
#  ('open specific hours', 7),
#  ('heated', 7),
#  ('free parking garage on premises u2013 1 space', 7),
#  ('childrenu2019s books and toys for ages 25 years old', 7),
#  ('fast wifi u2013 106 mbps', 7),
#  ('siemens oven', 7),
#  ('simple body soap', 6),
#  ('wifi u2013 37 mbps', 6),
#  ('childrenu2019s books and toys for ages 510 years old and 10 years old', 6),
#  ('various conditioner', 6),
#  ('stationary bike', 6),
#  ('bose bluetooth sound system', 6),
#  ('tv with dvd player', 6),
#  ('48 hdtv with netflix', 6),
#  ('aeg stainless steel gas stove', 6),
#  ('childrenu2019s books and toys for ages 25 years old and 510 years old', 6),
#  ('woodburning', 6),
#  ('tv with chromecast', 6),
#  ('ping pong table', 6),
#  ('wifi u2013 11 mbps', 6),
#  ('dryer u2013u00a0in unit', 6),
#  ('55 hdtv with chromecast', 6),
#  ('fast wifi u2013 104 mbps', 6),
#  ('tresemme conditioner', 6),
#  ('tresemme shampoo', 6),
#  ('fast wifi u2013 74 mbps', 6),
#  ('fast wifi u2013 72 mbps', 6),
#  ('paid parking garage on premises', 6),
#  ('other stainless steel gas stove', 6),
#  ('wifi u2013 34 mbps', 6),
#  ('paid washer', 6),
#  ('alexa sound system', 6),
#  ('shared indoor pool  available all year', 6),
#  ('faith in nature shampoo', 6),
#  ('tv with fire tv', 6),
#  ('fast wifi u2013 56 mbps', 6),
#  ('game console xbox 360', 6),
#  ('aesop shampoo', 6),
#  ('smeg stainless steel oven', 6),
#  ('fast wifi u2013 60 mbps', 5),
#  ('fast wifi u2013 146 mbps', 5),
#  ('bosch gas stove', 5),
#  ('game console ps5', 5),
#  ('fast wifi u2013 76 mbps', 5),
#  ('free resort access', 5),
#  ('36 hdtv', 5),
#  ('65 hdtv with netflix', 5),
#  ('aeg oven', 5),
#  ('50 hdtv with standard cable', 5),
#  ('46 hdtv with netflix', 5),
#  ('fast wifi u2013 57 mbps', 5),
#  ('dove shampoo', 5),
#  ('55 hdtv with standard cable', 5),
#  ('43 hdtv with standard cable', 5),
#  ('hotpoint stainless steel oven', 5),
#  ('50 tv', 5),
#  ('treadmill', 5),
#  ('other stainless steel electric stove', 5),
#  ('other induction stove', 5),
#  ('cien body soap', 5),
#  ('neff oven', 5),
#  ('60 hdtv with amazon prime video', 5),
#  ('fast wifi u2013 69 mbps', 5),
#  ('wifi u2013 46 mbps', 5),
#  ('wifi u2013 19 mbps', 5),
#  ('zanussi refrigerator', 5),
#  ('private gym in building', 5),
#  ('bosch induction stove', 5),
#  ('aesop conditioner', 5),
#  ('cien shampoo', 5),
#  ('38 hdtv with netflix', 5),
#  ('lake view', 5),
#  ('neff induction stove', 5),
#  ('49 hdtv with amazon prime video', 5),
#  ('siemens stainless steel oven', 5),
#  ('hulu', 5),
#  ('fast wifi u2013 62 mbps', 4),
#  ('eden  body soap', 4),
#  ('hdtv with dvd player', 4),
#  ('wifi u2013 49 mbps', 4),
#  ('sony bluetooth sound system', 4),
#  ('various shampoo', 4),
#  ('wifi u2013 17 mbps', 4),
#  ('fast wifi u2013 63 mbps', 4),
#  ('wifi u2013 25 mbps', 4),
#  ('dove conditioner', 4),
#  ('36 hdtv with netflix', 4),
#  ('42 tv with amazon prime video', 4),
#  ('bosch stainless steel gas stove', 4),
#  ('wifi u2013 6 mbps', 4),
#  ('tv with roku', 4),
#  ('22 tv with standard cable', 4),
#  ('ikea refrigerator', 4),
#  ('48 hdtv', 4),
#  ('cien conditioner', 4),
#  ('free driveway parking on premises u2013 3 spaces', 4),
#  ('sea kelp shampoo', 4),
#  ('wifi u2013 48 mbps', 4),
#  ('scottish fine soaps conditioner', 4),
#  ('wifi u2013 26 mbps', 4),
#  ('49 hdtv with netflix', 4),
#  ('booster seat high chair  available upon request', 4),
#  ('paid dryer', 4),
#  ('faith in nature body soap', 4),
#  ('whirlpool gas stove', 4),
#  ('fast wifi u2013 65 mbps', 4),
#  ('48 hdtv with amazon prime video', 4),
#  ('boat slip', 4),
#  ('miele refrigerator', 4),
#  ('smeg gas stove', 4),
#  ('fast wifi u2013 61 mbps', 4),
#  ('wifi u2013 13 mbps', 4),
#  ('pears body soap', 4),
#  ('belling stainless steel oven', 4),
#  ('fast wifi u2013 58 mbps', 4),
#  ('amazon alexa bluetooth sound system', 4),
#  ('na stainless steel gas stove', 4),
#  ('head and shoulders shampoo', 4),
#  ('na stainless steel electric stove', 4),
#  ('dove  body soap', 4),
#  ('fast wifi u2013 55 mbps', 4),
#  ('paid folding or convertible high chair  available upon request', 4),
#  ('shared pool', 3),
#  ('washer u2013u00a0in building', 3),
#  ('dryer u2013 in building', 3),
#  ('simple conditioner', 3),
#  ('24 tv', 3),
#  ('sonos  sound system', 3),
#  ('wifi u2013 23 mbps', 3),
#  ('65 hdtv with standard cable', 3),
#  ('42 hdtv with apple tv', 3),
#  ('belling oven', 3),
#  ('private sauna', 3),
#  ('wifi u2013 33 mbps', 3),
#  ('wifi u2013 9 mbps', 3),
#  ('wifi u2013 10 mbps', 3),
#  ('paid parking lot on premises u2013 2 spaces', 3),
#  ('generic conditioner', 3),
#  ('generic body soap', 3),
#  ('aeg stainless steel oven', 3),
#  ('wifi u2013 8 mbps', 3),
#  ('fast wifi u2013 252 mbps', 3),
#  ('48 hdtv with standard cable', 3),
#  ('faith in nature  shampoo', 3),
#  ('fast wifi u2013 102 mbps', 3),
#  ('32 tv with standard cable', 3),
#  ('smeg oven', 3),
#  ('loreal conditioner', 3),
#  ('wifi u2013 18 mbps', 3),
#  ('52 hdtv with standard cable', 3),
#  ('32 hdtv with apple tv', 3),
#  ('24 hdtv with amazon prime video', 3),
#  ('52 hdtv with netflix', 3),
#  ('free parking on premises u2013 2 spaces', 3),
#  ('fast wifi u2013 96 mbps', 3),
#  ('keurig coffee machine', 3),
#  ('sea kelp body soap', 3),
#  ('fast wifi u2013 66 mbps', 3),
#  ('fast wifi u2013 148 mbps', 3),
#  ('folding or convertible high chair', 3),
#  ('sun loungers', 3),
#  ('electric oven', 3),
#  ('32 tv with chromecast', 3),
#  ('siemens  induction stove', 3),
#  ('fast wifi u2013 77 mbps', 3),
#  ('bose sound system with bluetooth and aux', 3),
#  ('wifi u2013 40 mbps', 3),
#  ('private gym nearby', 3),
#  ('molton brown body soap', 3),
#  ('exercise equipment elliptical', 3),
#  ('wifi u2013 30 mbps', 3),
#  ('zanussi stainless steel oven', 3),
#  ('fast wifi u2013 141 mbps', 3),
#  ('private hot tub  available all year', 3),
#  ('open 24 hours', 3),
#  ('40 hdtv with premium cable', 3),
#  ('wifi u2013 14 mbps', 3),
#  ('bosch stove', 3),
#  ('fast wifi u2013 53 mbps', 3),
#  ('belling stainless steel gas stove', 3),
#  ('42 hdtv with premium cable', 3),
#  ('kenwood refrigerator', 3),
#  ('smeg  oven', 3),
#  ('32 tv with netflix', 3),
#  ('wifi u2013 47 mbps', 3),
#  ('hdtv with roku', 3),
#  ('fast wifi u2013 122 mbps', 3),
#  ('pool view', 3),
#  ('50 hdtv with fire tv', 3),
#  ('28 hdtv', 3),
#  ('65 hdtv with disney', 3),
#  ('aesop body soap', 3),
#  ('neff stainless steel stove', 3),
#  ('75 hdtv with amazon prime video', 3),
#  ('aeg refrigerator', 3),
#  ('pantene conditioner', 3),
#  ('fast wifi u2013 208 mbps', 3),
#  ('mason  miller body soap', 3),
#  ('fast wifi u2013 244 mbps', 2),
#  ('42 tv with standard cable', 2),
#  ('eden conditioner', 2),
#  ('indoor fireplace pellet stove', 2),
#  ('smeg fridgefreezer refrigerator', 2),
#  ('siemens stainless steel electric stove', 2),
#  ('scottish soap company body soap', 2),
#  ('fast wifi u2013 125 mbps', 2),
#  ('hotpoint oven', 2),
#  ('fast wifi u2013 225 mbps', 2),
#  ('fast wifi u2013 311 mbps', 2),
#  ('molton brown  body soap', 2),
#  ('fast wifi u2013 264 mbps', 2),
#  ('55 hdtv with disney', 2),
#  ('43 hdtv with chromecast', 2),
#  ('simple kind to skin gentle care handwash body soap', 2),
#  ('neils yard remidies body soap', 2),
#  ('fast wifi u2013 51 mbps', 2),
#  ('26 tv with netflix', 2),
#  ('clamp on table seat high chair  available upon request', 2),
#  ('fast wifi u2013 342 mbps', 2),
#  ('fast wifi u2013 68 mbps', 2),
#  ('panasonic sound system', 2),
#  ('fast wifi u2013 195 mbps', 2),
#  ('40 tv', 2),
#  ('free residential garage on premises u2013 2 spaces', 2),
#  ('bosch electric stove', 2),
#  ('loreal shampoo', 2),
#  ('fast wifi u2013 59 mbps', 2),
#  ('smeg stainless steel stove', 2),
#  ('free parking garage on premises', 2),
#  ('kitchenette', 2),
#  ('32 hdtv with roku', 2),
#  ('75 hdtv with netflix', 2),
#  ('wifi u2013 44 mbps', 2),
#  ('40 tv with netflix', 2),
#  ('beko induction stove', 2),
#  ('beko oven', 2),
#  ('scottish fine soaps  sea kelp body soap', 2),
#  ('scottish fine soaps  sea kelp shampoo', 2),
#  ('fast wifi u2013 197 mbps', 2),
#  ('whirlpool stainless steel oven', 2),
#  ('43 hdtv with dvd player', 2),
#  ('fast wifi u2013 117 mbps', 2),
#  ('44 hdtv with amazon prime video', 2),
#  ('scottish fine soap shampoo', 2),
#  ('sea kelp conditioner', 2),
#  ('arran aromatics conditioner', 2),
#  ('arran aromatics body soap', 2),
#  ('siemens  stainless steel oven', 2),
#  ('36 tv', 2),
#  ('out of eden body soap', 2),
#  ('26 hdtv with netflix', 2),
#  ('45 hdtv with amazon prime video', 2),
#  ('aeg induction stove', 2),
#  ('childrenu2019s books and toys for ages 10 years old', 2),
#  ('various  body soap', 2),
#  ('fast wifi u2013 143 mbps', 2),
#  ('pool toys', 2),
#  ('49 hdtv', 2),
#  ('fast wifi u2013 113 mbps', 2),
#  ('26 hdtv with amazon prime video', 2),
#  ('neff refrigerator', 2),
#  ('wifi u2013 12 mbps', 2),
#  ('denon bluetooth sound system', 2),
#  ('wifi u2013 4 mbps', 2),
#  ('sony sound system', 2),
#  ('john lewis stainless steel oven', 2),
#  ('molton brown shampoo', 2),
#  ('52 tv with amazon prime video', 2),
#  ('aeg electric stove', 2),
#  ('exercise equipment treadmill', 2),
#  ('clothing storage walkin closet and wardrobe', 2),
#  ('42 tv with netflix', 2),
#  ('fast wifi u2013 271 mbps', 2),
#  ('other gas stove', 2),
#  ('fast wifi u2013 206 mbps', 2),
#  ('fast wifi u2013 151 mbps', 2),
#  ('wifi u2013 7 mbps', 2),
#  ('wifi u2013 29 mbps', 2),
#  ('tbc body soap', 2),
#  ('faith in nature  body soap', 2),
#  ('head  shoulders shampoo', 2),
#  ('60 hdtv with premium cable', 2),
#  ('paid parking on premises u2013 1 space', 2),
#  ('50 hdtv with chromecast', 2),
#  ('alexa  bluetooth sound system', 2),
#  ('fast wifi u2013 198 mbps', 2),
#  ('bush  refrigerator', 2),
#  ('wifi u2013 39 mbps', 2),
#  ('fast wifi u2013 178 mbps', 2),
#  ('tv with apple tv', 2),
#  ('hotpoint  refrigerator', 2),
#  ('local conditioner', 2),
#  ('local shampoo', 2),
#  ('46 hdtv with amazon prime video', 2),
#  ('15 tv', 2),
#  ('36 hdtv with amazon prime video', 2),
#  ('pantene  shampoo', 2),
#  ('private outdoor kitchen', 2),
#  ('fast wifi u2013 115 mbps', 2),
#  ('43 hdtv with fire tv', 2),
#  ('aesop  body soap', 2),
#  ('47 hdtv with amazon prime video', 2),
#  ('43 hdtv with premium cable', 2),
#  ('paid parking garage on premises u2013 1 space', 2),
#  ('kenwood stainless steel gas stove', 2),
#  ('fast wifi u2013 135 mbps', 2),
#  ('game console nintendo switch', 2),
#  ('40 tv with amazon prime video', 2),
#  ('32 hdtv with disney', 2),
#  ('fast wifi u2013 134 mbps', 2),
#  ('fast wifi u2013 333 mbps', 2),
#  ('aeg stove', 2),
#  ('clamp on table seat high chair', 2),
#  ('candy refrigerator', 2),
#  ('other electric stove', 2),
#  ('different brands conditioner', 2),
#  ('38 hdtv with standard cable', 2),
#  ('fast wifi u2013 78 mbps', 2),
#  ('wifi u2013 45 mbps', 2),
#  ('58 hdtv with netflix', 2),
#  ('fast wifi u2013 436 mbps', 2),
#  ('duck island shampoo', 2),
#  ('duck island conditioner', 2),
#  ('duck island body soap', 2),
#  ('60 hdtv with fire tv', 2),
#  ('eco friendly conditioner', 2),
#  ('lamona stainless steel oven', 2),
#  ('indesit refrigerator', 2),
#  ('john lewis refrigerator', 2),
#  ('samsung stainless steel oven', 2),
#  ('neff gas stove', 2),
#  ('32 hdtv with fire tv', 2),
#  ('50 hdtv with apple tv', 2),
#  ('fast wifi u2013 228 mbps', 2),
#  ('fast wifi u2013 213 mbps', 2),
#  ('sonos  bluetooth sound system', 2),
#  ('bosch  oven', 2),
#  ('laura thomas co body soap', 2),
#  ('laura thomas co conditioner', 2),
#  ('laura thomas co shampoo', 2),
#  ('fast wifi u2013 147 mbps', 2),
#  ('resort view', 2),
#  ('garnier  shampoo', 2),
#  ('garnier conditioner', 2),
#  ('aeg stainless steel electric stove', 2),
#  ('75 hdtv', 2),
#  ('the white company shampoo', 2),
#  ('na stainless steel induction stove', 2),
#  ('fast wifi u2013 100 mbps', 2),
#  ('the scottish fine soaps company body soap', 2),
#  ('the scottish fine soaps company shampoo', 2),
#  ('samsung induction stove', 2),
#  ('aesop shower gel body soap', 2),
#  ('60 hdtv with netflix', 2),
#  ('tv with disney', 2),
#  ('heating  split type ductless system', 2),
#  ('kayak', 2),
#  ('lamona  oven', 2),
#  ('fast wifi u2013 103 mbps', 2),
#  ('pantene shampoo', 2),
#  ('mason  miller shampoo', 2),
#  ('tresseme  conditioner', 2),
#  ('fast wifi u2013 255 mbps', 2),
#  ('out of eden shampoo', 2),
#  ('fast wifi u2013 121 mbps', 2),
#  ('just for you shampoo', 2),
#  ('52 hdtv with amazon prime video', 1),
#  ('bose sound system with aux', 1),
#  ('50 tv with premium cable', 1),
#  ('fast wifi u2013 424 mbps', 1),
#  ('shared pool  ', 1),
#  ('26 tv with amazon prime video', 1),
#  ('43 tv', 1),
#  ('liquid hand soap body soap', 1),
#  ('pioneer sound system', 1),
#  ('range master  stainless steel electric stove', 1),
#  ('scottish soap company conditioner', 1),
#  ('80 hdtv with amazon prime video', 1),
#  ('sony bluetooth speaker bluetooth sound system', 1),
#  ('fan oven stainless steel oven', 1),
#  ('bosche oven', 1),
#  ('bosche induction stove', 1),
#  ('simple   sensitive skin experts shampoo', 1),
#  ('bloomberg stove', 1),
#  ('58 hdtv', 1),
#  ('48 tv with amazon prime video', 1),
#  ('maria nila  shampoo', 1),
#  ('maria nila  conditioner', 1),
#  ('36 tv with apple tv', 1),
#  ('hot point  stainless steel oven', 1),
#  ('better you bring your own because of that we only provide very standard shampoo and conditioner 2 in 1 type  conditioner',
#   1),
#  ('fast wifi u2013 214 mbps', 1),
#  ('60 tv', 1),
#  ('electric stand alone oven on bench top suitable for baking dishes  oven',
#   1),
#  ('house of eden body soap', 1),
#  ('rituals  shampoo', 1),
#  ('rituals  conditioner', 1),
#  ('100 hdtv with chromecast', 1),
#  ('fast wifi u2013 369 mbps', 1),
#  ('fast wifi u2013 226 mbps', 1),
#  ('pantene smooth and sleek conditioner', 1),
#  ('simple shampoo', 1),
#  ('pantene smooth and sleek shampoo', 1),
#  ('generic refrigerator', 1),
#  ('generic sound system', 1),
#  ('generic oven', 1),
#  ('dook body soap', 1),
#  ('shower gel body soap', 1),
#  ('fast wifi u2013 254 mbps', 1),
#  ('paid parking lot on premises u2013 5 spaces', 1),
#  ('you will have a bottle of versatile shower gel for yourself to use but you aslo can use any our shower products  body soap',
#   1),
#  ('verona stainless steel gas stove', 1),
#  ('lacura shampoo', 1),
#  ('several types  conditioner', 1),
#  ('several types  body soap', 1),
#  ('37 hdtv with apple tv', 1),
#  ('32 hdtv with premium cable', 1),
#  ('25 tv', 1),
#  ('fast wifi u2013 82 mbps', 1),
#  ('28 hdtv with standard cable', 1),
#  ('fast wifi u2013 280 mbps', 1),
#  ('24 tv with chromecast', 1),
#  ('dove and sanex body soap', 1),
#  ('16 tv', 1),
#  ('john lewis  refrigerator', 1),
#  ('fast wifi u2013 445 mbps', 1),
#  ('24 hdtv with chromecast', 1),
#  ('organic  body soap', 1),
#  ('natural body soap', 1),
#  ('ikea electric stove', 1),
#  ('fast wifi u2013 287 mbps', 1),
#  ('beco refrigerator', 1),
#  ('for first night body soap', 1),
#  ('for first day shampoo', 1),
#  ('42 tv with chromecast', 1),
#  ('5 ring mains gas hob gas stove', 1),
#  ('hand wash', 1),
#  ('body wash  shampoo', 1),
#  ('conditioner body soap', 1),
#  ('27 tv', 1),
#  ('various  shampoo', 1),
#  ('small anker portable bluetooth speaker  bluetooth sound system', 1),
#  ('sony receiver for 51 surround sound system with aux', 1),
#  ('zanussi stainless steel gas stove', 1),
#  ('hitachi sound system with aux', 1),
#  ('a small under counter fridge with small freezer compartment  refrigerator',
#   1),
#  ('under counter fridge with freezer shelf on top refrigerator', 1),
#  ('jbl bluetooth speaker sound system with bluetooth and aux', 1),
#  ('40 hdtv with disney', 1),
#  ('organic body soap', 1),
#  ('gas  stainless steel oven', 1),
#  ('cole  lewis body soap', 1),
#  ('cole lewis shampoo', 1),
#  ('refigerader refrigerator', 1),
#  ('gas stainless steel gas stove', 1),
#  ('cole and lewis conditioner', 1),
#  (' neils yard remedies body soap', 1),
#  ('fast wifi u2013 133 mbps', 1),
#  ('indesit  electric stove', 1),
#  ('33 tv with standard cable', 1),
#  ('35 hdtv with chromecast', 1),
#  ('bose sound system', 1),
#  ('30 tv with dvd player', 1),
#  ('belling electric stove', 1),
#  ('varies body soap', 1),
#  ('fast wifi u2013 352 mbps', 1),
#  ('fast wifi u2013 131 mbps', 1),
#  ('beko fridge freezer refrigerator', 1),
#  ('scottish fine soaps  sea kelp conditioner', 1),
#  ('hotpoint  stainless steel gas stove', 1),
#  ('wifi u2013 32 mbps', 1),
#  ('33 hdtv with apple tv', 1),
#  ('fast wifi u2013 142 mbps', 1),
#  ('luxury environmentally friendly conditioner supplied by local plastic free shop conditioner',
#   1),
#  ('luxury environmentally friendly soap supplied by local plastic free shop body soap',
#   1),
#  ('luxury environmentally friendly shampoo supplied by local plastic free shop shampoo',
#   1),
#  ('miele induction stove', 1),
#  ('lamona refrigerator', 1),
#  ('lamona induction stove', 1),
#  ('head and shoulders conditioner', 1),
#  ('19 hdtv', 1),
#  ('lg soundbar bluetooth sound system', 1),
#  ('fast wifi u2013 116 mbps', 1),
#  ('fast wifi u2013 188 mbps', 1),
#  ('juiceboom bluetooth sound system', 1),
#  ('45 hdtv with netflix', 1),
#  ('scottish fine soaps company shampoo', 1),
#  ('scottish fine soaps company body soap', 1),
#  ('sauna', 1),
#  ('32 tv with amazon prime video', 1),
#  ('friendly hair and body bar shampoo', 1),
#  ('friendly body soap', 1),
#  ('yamaha', 1),
#  ('jongo sound system with bluetooth and aux', 1),
#  ('private gym', 1),
#  ('denon sound system', 1),
#  ('neff stainless steel gas stove', 1),
#  ('waitrose shower gel body soap', 1),
#  ('siemens american fridge freezer  refrigerator', 1),
#  ('58 hdtv with premium cable', 1),
#  ('clamp on table seat high chair  always at the listing', 1),
#  ('environmentally friendly brands of body wash and shampoo in the shower body soap',
#   1),
#  ('scottish conditioner', 1),
#  ('muji bluetooth sound system', 1),
#  ('scottish body soap', 1),
#  ('argan oil shampoo', 1),
#  ('argan oil conditioner', 1),
#  ('fast wifi u2013 406 mbps', 1),
#  ('tresemmu00e9 shampoo', 1),
#  ('tresemmu00e9 conditioner', 1),
#  ('3 hdtv with standard cable', 1),
#  ('wifi u2013 43 mbps', 1),
#  ('vo5 shampoo', 1),
#  ('vo5 conditioner', 1),
#  ('sainsburyu2019s body soap', 1),
#  ('wifi u2013 20 mbps', 1),
#  ('wifi u2013 27 mbps', 1),
#  ('jbl on stage iii sound system with aux', 1),
#  ('fast wifi u2013 478 mbps', 1),
#  ('miele stainless steel induction stove', 1),
#  ('branded or waitrose body soap', 1),
#  ('branded or waitrose conditioner', 1),
#  ('fast wifi u2013 309 mbps', 1),
#  ('fast wifi u2013 486 mbps', 1),
#  ('skiinskiout', 1),
#  ('through samsung serif tv bluetooth sound system', 1),
#  ('aeg gas stove', 1),
#  ('portable 2 ring hob electric stove', 1),
#  ('highland soap company body soap', 1),
#  ('free parking on premises u2013 6 spaces', 1),
#  ('46 hdtv', 1),
#  ('uncounter fridgefreezer refrigerator', 1),
#  ('uconnect bluetooth sound system', 1),
#  ('with freezer compartment refrigerator', 1),
#  ('28 tv with amazon prime video', 1),
#  ('42 hdtv with roku', 1),
#  (' dove body soap', 1),
#  ('treseme shampoo', 1),
#  ('28 tv with premium cable', 1),
#  ('ikea stainless steel gas stove', 1),
#  ('ikea oven', 1),
#  ('28 hdtv with amazon prime video', 1),
#  ('ikea  induction stove', 1),
#  ('locally made from the fine soap co  body soap', 1),
#  ('24 hdtv with standard cable', 1),
#  ('marku2019s and spencers body soap', 1),
#  ('fast wifi u2013 161 mbps', 1),
#  ('14 hdtv', 1),
#  ('ms bath shower products plus loreal men 5in1 body soap', 1),
#  ('travel size bluetooth speaker sound system', 1),
#  ('liebherr refrigerator', 1),
#  ('panasonic sound system with bluetooth and aux', 1),
#  ('ms body soap', 1),
#  ('ms conditioner', 1),
#  ('ms shampoo', 1),
#  ('fast wifi u2013 149 mbps', 1),
#  ('50 tv with amazon prime video', 1),
#  ('boots  conditioner', 1),
#  ('44 tv with standard cable', 1),
#  ('fast wifi u2013 88 mbps', 1),
#  ('fast wifi u2013 425 mbps', 1),
#  ('naim  pro ac bluetooth sound system', 1),
#  ('fast wifi u2013 138 mbps', 1),
#  ('arbonne body soap', 1),
#  ('arbonne conditioner', 1),
#  ('arbonne shampoo', 1),
#  ('fast wifi u2013 455 mbps', 1),
#  ('homemade or branded body soap', 1),
#  ('olaplex conditioner', 1),
#  ('54 hdtv with premium cable', 1),
#  ('noble isle  conditioner', 1),
#  ('fast wifi u2013 204 mbps', 1),
#  ('30 hdtv with standard cable', 1),
#  ('no microwave at this property stove', 1),
#  ('free weights', 1),
#  ('sainsburys body soap', 1),
#  ('sainsburys conditioner', 1),
#  ('fast wifi u2013 191 mbps', 1),
#  ('good quality organic general use shampoo shampoo', 1),
#  ('dr bronner organic hair and body soap body soap', 1),
#  ('good quality organic general use conditioner conditioner', 1),
#  ('free parking garage on premises u2013 2 spaces', 1),
#  ('yamaha soundbar sound system', 1),
#  ('43 tv with standard cable', 1),
#  ('miele stainless steel oven', 1),
#  ('roberts sound system', 1),
#  ('24 tv with standard cable', 1),
#  ('tbc conditioner', 1),
#  ('30 tv', 1),
#  ('fast wifi u2013 168 mbps', 1),
#  ('large american fridge refrigerator', 1),
#  ('induction stove tophob stove', 1),
#  ('bosch  stainless steel oven', 1),
#  ('wifi u2013 22 mbps', 1),
#  ('echo dot bluetooth sound system', 1),
#  ('coffee maker keurig coffee machine', 1),
#  ('technics sound system with aux', 1),
#  ('48 hdtv with chromecast', 1),
#  ('game console ps3 and ps4', 1),
#  ('various in room body soap', 1),
#  ('various in room  conditioner', 1),
#  ('ksboombar bluetooth sound system', 1),
#  ('fancy body soap', 1),
#  ('fancy conditioner', 1),
#  ('fancy  shampoo', 1),
#  ('google  sound system', 1),
#  ('85 hdtv with standard cable', 1),
#  ('siemens  oven', 1),
#  ('with small freezer compartment  refrigerator', 1),
#  ('nobal isle body soap', 1),
#  ('marshall sound system with bluetooth and aux', 1),
#  ('indesit  oven', 1),
#  ('bose bluetooth  sound system', 1),
#  ('connect to tv samsung soundbar bluetooth sound system', 1),
#  ('herbal essences  conditioner', 1),
#  ('wifi u2013 24 mbps', 1),
#  ('fast wifi u2013 92 mbps', 1),
#  ('essentials shampoo', 1),
#  ('sony and bose sound system with bluetooth and aux', 1),
#  ('essentials conditioner', 1),
#  ('46 tv with standard cable', 1),
#  ('cambridge audio sound system', 1),
#  ('faith in nature  organic  rose  shampoo', 1),
#  ('ikea  sound system with bluetooth and aux', 1),
#  ('faith in nature organic  rose  conditioner', 1),
#  ('non perfumed sensitive skin body soap', 1),
#  ('non perfumed sensitive  shampoo', 1),
#  ('non perfumed sensative conditioner', 1),
#  ('friendly soap company body soap', 1),
#  ('alternative simple conditioner conditioner', 1),
#  ('alternative simple shampoo shampoo', 1),
#  ('50 tv with roku', 1),
#  ('baumatic stainless steel oven', 1),
#  ('the scottish fine soaps company  conditioner', 1),
#  ('baumatic gas stove', 1),
#  ('the scottish fine soaps company  shampoo', 1),
#  ('local body soap', 1),
#  ('google sound system', 1),
#  ('american  refrigerator', 1),
#  ('fast wifi u2013 212 mbps', 1),
#  ('pantene prov or herbal essences biorenew  conditioner', 1),
#  ('pantene prov or herbal essences biorenew  shampoo', 1),
#  ('indoor fireplace ethanol', 1),
#  ('33 hdtv', 1),
#  ('amazon echo sound system with bluetooth and aux', 1),
#  ('fast wifi u2013 502 mbps', 1),
#  ('cd player with a selection of cd  digital radio with bluetooth connection and ipodiphone charger sound system with bluetooth and aux',
#   1),
#  ...]

# %% [markdown]
# Models
# _________________________________

# %%
quality_df = quality_df.drop(quality_df[quality_df['price']>10000].index)


plt.figure(figsize=(6,6))
sns.scatterplot(x='room_type_num', y='price', data=quality_df)

plt.xlabel("room_type_num", size=13)
plt.ylabel("price", size=13)
plt.title("room_type_num vs price",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'room_type_num vs price')

# %%
plt.figure(figsize=(10,10))
sns.histplot(quality_df['price'])
plt.title("Price Distribution Plot",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Price Distribution Plot')

# %%
quality_df['price_log'] = np.log(quality_df.price + 1)

plt.figure(figsize=(12,10))
sns.histplot(quality_df['price_log'])
plt.title("Log-Price Distribution Plot",size=15, weight='bold')
# Out:
# Text(0.5, 1.0, 'Log-Price Distribution Plot')

# %%
plt.figure(figsize=(7,7))
stats.probplot(quality_df['price_log'], plot=plt)
plt.show()

# %%
columns = ['name', 'host_response_time', 'neighbourhood_cleansed','amenities','host_id', ]
quality_df.drop(columns=columns, inplace=True)
quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5239 entries, 0 to 7387
# Data columns (total 45 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5239 non-null   float64
#  1   host_response_rate                            5239 non-null   float64
#  2   host_acceptance_rate                          5239 non-null   float64
#  3   host_is_superhost                             5239 non-null   float64
#  4   host_listings_count                           5239 non-null   int64
#  5   host_total_listings_count                     5239 non-null   int64
#  6   host_has_profile_pic                          5239 non-null   int64
#  7   host_identity_verified                        5239 non-null   int64
#  8   accommodates                                  5239 non-null   int64
#  9   bathrooms                                     5239 non-null   float64
#  10  bedrooms                                      5239 non-null   float64
#  11  beds                                          5239 non-null   float64
#  12  price                                         5239 non-null   float64
#  13  minimum_nights                                5239 non-null   int64
#  14  maximum_nights                                5239 non-null   int64
#  15  minimum_minimum_nights                        5239 non-null   int64
#  16  maximum_minimum_nights                        5239 non-null   int64
#  17  minimum_maximum_nights                        5239 non-null   int64
#  18  maximum_maximum_nights                        5239 non-null   int64
#  19  minimum_nights_avg_ntm                        5239 non-null   float64
#  20  maximum_nights_avg_ntm                        5239 non-null   float64
#  21  has_availability                              5239 non-null   int64
#  22  availability_30                               5239 non-null   int64
#  23  availability_60                               5239 non-null   int64
#  24  availability_90                               5239 non-null   int64
#  25  availability_365                              5239 non-null   int64
#  26  number_of_reviews                             5239 non-null   int64
#  27  number_of_reviews_ltm                         5239 non-null   int64
#  28  number_of_reviews_l30d                        5239 non-null   int64
#  29  review_scores_rating                          5239 non-null   float64
#  30  review_scores_accuracy                        5239 non-null   float64
#  31  review_scores_cleanliness                     5239 non-null   float64
#  32  review_scores_checkin                         5239 non-null   float64
#  33  review_scores_communication                   5239 non-null   float64
#  34  review_scores_location                        5239 non-null   float64
#  35  review_scores_value                           5239 non-null   float64
#  36  instant_bookable                              5239 non-null   int64
#  37  calculated_host_listings_count                5239 non-null   int64
#  38  calculated_host_listings_count_entire_homes   5239 non-null   int64
#  39  calculated_host_listings_count_private_rooms  5239 non-null   int64
#  40  calculated_host_listings_count_shared_rooms   5239 non-null   int64
#  41  Parking                                       5239 non-null   int64
#  42  room_type_num                                 5239 non-null   int64
#  43  host_response_time_num                        5239 non-null   int64
#  44  price_log                                     5239 non-null   float64
# dtypes: float64(18), int64(27)
# memory usage: 1.8 MB

# %%
quality_df_x, quality_df_y = quality_df.iloc[:,:-1], quality_df.iloc[:,-1]
quality_df_x = pd.DataFrame(quality_df_x, columns=quality_df.columns[:-1])


# scaler = StandardScaler()
# quality_df_x = scaler.fit_transform(quality_df_x)
# quality_df_x = pd.DataFrame(quality_df_x, columns=quality_df.columns[:-1])

# %%
# f, axes = plt.subplots(5, 2, figsize=(15, 20))
# sns.residplot(quality_df_x.iloc[:,0],quality_df_y, lowess=True, ax=axes[0, 0], 
#                           scatter_kws={'alpha': 0.5}, 
#                           line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

# %%
# Random Forest Prediction Feature
X_train, X_test, y_train, y_test = train_test_split(
quality_df.drop(columns=['price']), quality_df['price'], test_size=0.3, random_state=42)

# Create an instance of the RandomForestRegressor class
rf_reg = RandomForestRegressor(random_state=42)

# Train the model on the training set
rf_reg.fit(X_train, y_train)

# Get the feature importances
feature_importances = rf_reg.feature_importances_

# Print the feature importances
print("Feature importances:\n")
for feature, importance in zip(X_train.columns, feature_importances):
    print(f"{feature}: {importance}")

# Select the top k features with the highest importance scores
k = 5
top_k_features = X_train.columns[np.argsort(feature_importances)[::-1][:k]]
print(f"\nTop {k} features: {list(top_k_features)}")


# Plot the feature importances for the top k features
plt.figure(figsize=(8, 6))
plt.bar(top_k_features, feature_importances[np.argsort(feature_importances)[::-1][:k]])
plt.xticks(rotation=45)
plt.xlabel('Features')
plt.ylabel('Importance Scores')
plt.title('Feature Importances')
plt.show()
# Out:
# Feature importances:
#
# id: 0.0002885074085588589
# host_response_rate: 8.865987610404271e-05
# host_acceptance_rate: 1.2748784598686762e-05
# host_is_superhost: 0.0034044992837873687
# host_listings_count: 0.0022834850953198835
# host_total_listings_count: 9.236981418988303e-05
# host_has_profile_pic: 7.302403198106972e-11
# host_identity_verified: 5.134812975597498e-09
# accommodates: 0.005631232654828202
# bathrooms: 0.0003770192603825118
# bedrooms: 0.0011481368173868072
# beds: 0.0014892027607727998
# minimum_nights: 0.00030149873246895537
# maximum_nights: 0.0015890778260286356
# minimum_minimum_nights: 0.00030919234663151496
# maximum_minimum_nights: 0.00017688493608949423
# minimum_maximum_nights: 0.00033580104243286055
# maximum_maximum_nights: 0.0002372327211129979
# minimum_nights_avg_ntm: 5.8140301850659074e-05
# maximum_nights_avg_ntm: 0.0007665816503706892
# has_availability: 6.81642901160622e-11
# availability_30: 0.00021497245364585614
# availability_60: 0.00029204504136165054
# availability_90: 0.000311622535940388
# availability_365: 0.00013807380896646384
# number_of_reviews: 0.00044069348015892177
# number_of_reviews_ltm: 0.0005589796380394551
# number_of_reviews_l30d: 9.664846971614902e-05
# review_scores_rating: 0.00014528177317533423
# review_scores_accuracy: 0.006162972750354367
# review_scores_cleanliness: 0.005264273084381173
# review_scores_checkin: 0.00027126614759725727
# review_scores_communication: 0.002783773452107948
# review_scores_location: 0.0017614343361666523
# review_scores_value: 0.0028766552057591255
# instant_bookable: 2.0364380118861456e-06
# calculated_host_listings_count: 0.0018797058972047516
# calculated_host_listings_count_entire_homes: 0.0007828211366537416
# calculated_host_listings_count_private_rooms: 0.0022417937952235105
# calculated_host_listings_count_shared_rooms: 3.703612158681362e-10
# Parking: 0.0023484260648675196
# room_type_num: 0.0002300529770367155
# host_response_time_num: 6.951072683029029e-07
# price_log: 0.9526054994470855
#
# Top 5 features: ['price_log', 'review_scores_accuracy', 'accommodates', 'review_scores_cleanliness', 'host_is_superhost']

# %%
### Linear Regression ###

def linear_reg(input_x, input_y, cv=5):
    ## Defining parameters
    model_LR= LinearRegression()

    parameters = {'fit_intercept':[True,False],  'copy_X':[True, False]}

    ## Building Grid Search algorithm with cross-validation and Mean Squared Error score.

    grid_search_LR = GridSearchCV(estimator=model_LR,  
                         param_grid=parameters,
                         scoring='neg_mean_squared_error',
                         cv=cv,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.

    grid_search_LR.fit(input_x, input_y)
    best_parameters_LR = grid_search_LR.best_params_  
    best_score_LR = grid_search_LR.best_score_ 
    print(best_parameters_LR)
    print(best_score_LR)


linear_reg(quality_df_x, quality_df_y)
# Out:
# {'copy_X': True, 'fit_intercept': True}
# -0.3036587528885859

# %%
### Ridge Regression ###

def ridge_reg(input_x, input_y, cv=5):
    ## Defining parameters
    model_Ridge= Ridge()

    # prepare a range of alpha values to test
    alphas = np.array([1,0.1,0.01,0.001,0.0001,0])
    normalizes= ([True,False])

    ## Building Grid Search algorithm with cross-validation and Mean Squared Error score.

    grid_search_Ridge = GridSearchCV(estimator=model_Ridge,  
                         param_grid=(dict(alpha=alphas)),
                         scoring='neg_mean_squared_error',
                         cv=cv,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.

    grid_search_Ridge.fit(input_x, input_y)
    best_parameters_Ridge = grid_search_Ridge.best_params_  
    best_score_Ridge = grid_search_Ridge.best_score_ 
    print(best_parameters_Ridge)
    print(best_score_Ridge)
    
ridge_reg(quality_df_x, quality_df_y)
# Out:
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.9661e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.30232e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.76956e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.74322e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.41002e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.86692e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.19905e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.04656e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.65702e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.24715e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.15511e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.98873e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.12963e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.87473e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.19755e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.63603e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.9677e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.12708e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.85755e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.19259e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.63393e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.9656e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.85583e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.12682e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.19209e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.96536e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.6337e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.85564e-39): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.12679e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.19204e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# {'alpha': 1.0}
# -0.16109340692307467
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.05039e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
### Lasso Regression ###

def lasso_reg(input_x, input_y, cv=5):
    ## Defining parameters
    model_Lasso= Lasso()

    # prepare a range of alpha values to test
    alphas = np.array([1,0.1,0.01,0.001,0.0001,0])
    normalizes= ([True,False])

    ## Building Grid Search algorithm with cross-validation and Mean Squared Error score.

    grid_search_lasso = GridSearchCV(estimator=model_Lasso,  
                         param_grid=(dict(alpha=alphas)),
                         scoring='neg_mean_squared_error',
                         cv=cv,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.

    grid_search_lasso.fit(input_x, input_y)
    best_parameters_lasso = grid_search_lasso.best_params_  
    best_score_lasso = grid_search_lasso.best_score_ 
    print(best_parameters_lasso)
    print(best_score_lasso)

lasso_reg(quality_df_x, quality_df_y)
# Out:
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.725e+02, tolerance: 1.670e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.658e+02, tolerance: 1.675e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.220e+02, tolerance: 1.750e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.281e+02, tolerance: 1.616e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.707e+02, tolerance: 1.730e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.718e+02, tolerance: 1.750e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.645e+02, tolerance: 1.670e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.579e+02, tolerance: 1.675e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.613e+02, tolerance: 1.730e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.622e+02, tolerance: 1.750e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.198e+02, tolerance: 1.616e-01
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.635e+02, tolerance: 1.670e-01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.569e+02, tolerance: 1.675e-01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.187e+02, tolerance: 1.616e-01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.609e+02, tolerance: 1.750e-01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.601e+02, tolerance: 1.730e-01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# {'alpha': 0.001}
# -0.14144750963597297
# /Users/arneshsaha/miniforge3/envs/fds/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.316e+02, tolerance: 2.112e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
kfold_cv=KFold(n_splits=5, random_state=42, shuffle=True)
for train_index, test_index in kfold_cv.split(quality_df_x, quality_df_y):
    X_train, X_test = quality_df_x[train_index], quality_df_x[test_index]
    y_train, y_test = quality_df_y[train_index], quality_df_y[test_index]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 3
#       1 kfold_cv=KFold(n_splits=5, random_state=42, shuffle=True)
#       2 for train_index, test_index in kfold_cv.split(quality_df_x, quality_df_y):
# ----> 3     X_train, X_test = quality_df_x[train_index], quality_df_x[test_index]
#       4     y_train, y_test = quality_df_y[train_index], quality_df_y[test_index]
#
# File ~/miniforge3/envs/fds/lib/python3.10/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniforge3/envs/fds/lib/python3.10/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/envs/fds/lib/python3.10/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([   0,    1,    2,    3,    4,    5,    6,    7,    9,   10,\n            ...\n            5223, 5224, 5226, 5228, 5229, 5231, 5235, 5236, 5237, 5238],\n           dtype='int64', length=4191)] are in the [columns]"

# %%
col1 =['review_scores_accuracy','review_scores_rating', 'price','room_type_num', 'Parking','host_response_time_num', 'bedrooms','beds','bathrooms','availability_30']

reviewCol = ['review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location',
        'review_scores_value']

corr = quality_df[reviewCol].corr(method='kendall')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
# Choose the column you want to plot against all other columns
col_to_print = 'price'

# Calculate the correlation between the chosen column and all other columns
correlations = quality_df.corr()[col_to_print]

for col, corr in correlations.items():
    if col != col_to_print:
        print(f"Correlation between {col_to_print} and {col}: {corr:.2f}")
# Out:
# Correlation between price and host_response_rate: -0.02
# Correlation between price and host_acceptance_rate: 0.02
# Correlation between price and host_is_superhost: -0.01
# Correlation between price and host_listings_count: 0.05
# Correlation between price and host_total_listings_count: 0.04
# Correlation between price and host_has_profile_pic: 0.01
# Correlation between price and host_identity_verified: 0.03
# Correlation between price and accommodates: 0.25
# Correlation between price and bathrooms: 0.27
# Correlation between price and bedrooms: 0.28
# Correlation between price and beds: 0.20
# Correlation between price and minimum_nights: 0.01
# Correlation between price and maximum_nights: 0.01
# Correlation between price and minimum_minimum_nights: 0.04
# Correlation between price and maximum_minimum_nights: 0.02
# Correlation between price and minimum_maximum_nights: -0.02
# Correlation between price and maximum_maximum_nights: -0.01
# Correlation between price and minimum_nights_avg_ntm: 0.02
# Correlation between price and maximum_nights_avg_ntm: -0.02
# Correlation between price and has_availability: -0.00
# Correlation between price and availability_30: 0.03
# Correlation between price and availability_60: 0.02
# Correlation between price and availability_90: 0.02
# Correlation between price and availability_365: 0.03
# Correlation between price and number_of_reviews: -0.05
# Correlation between price and number_of_reviews_ltm: -0.06
# Correlation between price and number_of_reviews_l30d: -0.07
# Correlation between price and review_scores_rating: -0.02
# Correlation between price and review_scores_accuracy: -0.01
# Correlation between price and review_scores_cleanliness: -0.02
# Correlation between price and review_scores_checkin: -0.01
# Correlation between price and review_scores_communication: -0.04
# Correlation between price and review_scores_location: 0.02
# Correlation between price and review_scores_value: -0.03
# Correlation between price and instant_bookable: 0.03
# Correlation between price and calculated_host_listings_count: 0.02
# Correlation between price and calculated_host_listings_count_entire_homes: 0.03
# Correlation between price and calculated_host_listings_count_private_rooms: -0.02
# Correlation between price and calculated_host_listings_count_shared_rooms: -0.02
# Correlation between price and Parking: -0.04
# Correlation between price and room_type_num: -0.12
# Correlation between price and host_response_time_num: 0.01
# Correlation between price and price_log: 0.54
