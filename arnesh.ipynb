# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
listings_filepath = '/Users/arneshsaha/Desktop/AirBnb/datasets/listings.csv'
listings_filepath
# Out:
# '/Users/arneshsaha/Desktop/AirBnb/datasets/listings.csv'

# %%
listings_df = pd.read_csv(listings_filepath)
listings_df.head(5)
# Out:
#          id                          listing_url     scrape_id last_scraped  \
# 0   15420.0   https://www.airbnb.com/rooms/15420  2.022120e+13   16/12/2022
# 1  707097.0  https://www.airbnb.com/rooms/707097  2.022120e+13   16/12/2022
# 2  728199.0  https://www.airbnb.com/rooms/728199  2.022120e+13   16/12/2022
# 3  732008.0  https://www.airbnb.com/rooms/732008  2.022120e+13   16/12/2022
# 4  744710.0  https://www.airbnb.com/rooms/744710  2.022120e+13   16/12/2022
#
#         source                                               name  \
# 0  city scrape                  Georgian Boutique Apt City Centre
# 1  city scrape  Centre Royal Mile Apartment 3 bedrooms 2 bathr...
# 2  city scrape   Private room in central, spacious and comfy flat
# 3  city scrape                          51 18 Caledonian Crescent
# 4  city scrape  Refurbished Flat in a Georgian Era Building in...
#
#                                          description  \
# 0  Stunning, spacious ground floor apartment minu...
# 1                                                NaN
# 2  Fantastic main door flat over two levels withi...
# 3  This beautiful third floor apartment is set in...
# 4  A stunning apartment in the heart of Edinburgh...
#
#                                neighborhood_overview  \
# 0  The neighbourhood is in the historic New Town,...
# 1  The location is the perfect for tourism , shor...
# 2  Great location for access to the city centre, ...
# 3                                                NaN
# 4  The apartment is in a Central Edinburgh neighb...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/cf69631f-4194...    60423  ...
# 1  https://a0.muscache.com/pictures/6e2ded8d-f20b...  3092851  ...
# 2  https://a0.muscache.com/pictures/11315577/0091...  3776412  ...
# 3  https://a0.muscache.com/pictures/prohost-api/H...  3810279  ...
# 4  https://a0.muscache.com/pictures/monet/Select-...  3737047  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.98                   4.98                4.91
# 1                        4.72                   4.94                4.09
# 2                        4.97                   4.73                4.79
# 3                        4.81                   4.71                4.70
# 4                        4.96                   4.96                4.86
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                t                              8
# 2     NaN                f                              1
# 3     NaN                t                              2
# 4     NaN                t                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           6
# 2                                           0
# 3                                           2
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            2
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              3.10
# 1                                           0              0.55
# 2                                           0              2.86
# 3                                           0              2.27
# 4                                           0              1.73
#
# [5 rows x 75 columns]

# %% [markdown]
# Data Cleaning

# %% [markdown]
# 1. neighbourhood_group_cleansed (Check if the whole column is empty)

# %%
nbr_grp_notnull = listings_df[listings_df['neighbourhood_group_cleansed'].isnull()]
nbr_grp_notnull
# Out:
#             id                          listing_url     scrape_id  \
# 0      15420.0   https://www.airbnb.com/rooms/15420  2.022120e+13
# 1     707097.0  https://www.airbnb.com/rooms/707097  2.022120e+13
# 2     728199.0  https://www.airbnb.com/rooms/728199  2.022120e+13
# 3     732008.0  https://www.airbnb.com/rooms/732008  2.022120e+13
# 4     744710.0  https://www.airbnb.com/rooms/744710  2.022120e+13
# ...        ...                                  ...           ...
# 7384  362653.0  https://www.airbnb.com/rooms/362653  2.022120e+13
# 7385  363642.0  https://www.airbnb.com/rooms/363642  2.022120e+13
# 7386  376937.0  https://www.airbnb.com/rooms/376937  2.022120e+13
# 7387  388297.0  https://www.airbnb.com/rooms/388297  2.022120e+13
# 7388  389318.0  https://www.airbnb.com/rooms/389318  2.022120e+13
#
#      last_scraped           source  \
# 0      16/12/2022      city scrape
# 1      16/12/2022      city scrape
# 2      16/12/2022      city scrape
# 3      16/12/2022      city scrape
# 4      16/12/2022      city scrape
# ...           ...              ...
# 7384   16/12/2022  previous scrape
# 7385   16/12/2022      city scrape
# 7386   16/12/2022  previous scrape
# 7387   16/12/2022      city scrape
# 7388   16/12/2022      city scrape
#
#                                                    name  \
# 0                     Georgian Boutique Apt City Centre
# 1     Centre Royal Mile Apartment 3 bedrooms 2 bathr...
# 2      Private room in central, spacious and comfy flat
# 3                             51 18 Caledonian Crescent
# 4     Refurbished Flat in a Georgian Era Building in...
# ...                                                 ...
# 7384                   Papermill Wynd Chiara Apartment,
# 7385                 Wonderful/beautiful room Edinburgh
# 7386                         Dario Apartment, Edinburgh
# 7387  Stunning villa by Holyrood Park -parking & gar...
# 7388  City centre. Walk to Castle, Museum etc. Own b...
#
#                                             description  \
# 0     Stunning, spacious ground floor apartment minu...
# 1                                                   NaN
# 2     Fantastic main door flat over two levels withi...
# 3     This beautiful third floor apartment is set in...
# 4     A stunning apartment in the heart of Edinburgh...
# ...                                                 ...
# 7384  <b>The space</b><br />Located just off McDonal...
# 7385  <b>The space</b><br />Room over looking the Pe...
# 7386  <b>The space</b><br />Dario is a new modern ap...
# 7387  On the doorstep of Arthur's Seat and Holyrood ...
# 7388  The Space<br />Situated in a quiet Mews courty...
#
#                                   neighborhood_overview  \
# 0     The neighbourhood is in the historic New Town,...
# 1     The location is the perfect for tourism , shor...
# 2     Great location for access to the city centre, ...
# 3                                                   NaN
# 4     The apartment is in a Central Edinburgh neighb...
# ...                                                 ...
# 7384                                                NaN
# 7385  Close to the city centre.  But surrounded by g...
# 7386                                                NaN
# 7387                                                NaN
# 7388  Southside is a bustling, vibrant, local commun...
#
#                                             picture_url  host_id  ...  \
# 0     https://a0.muscache.com/pictures/cf69631f-4194...    60423  ...
# 1     https://a0.muscache.com/pictures/6e2ded8d-f20b...  3092851  ...
# 2     https://a0.muscache.com/pictures/11315577/0091...  3776412  ...
# 3     https://a0.muscache.com/pictures/prohost-api/H...  3810279  ...
# 4     https://a0.muscache.com/pictures/monet/Select-...  3737047  ...
# ...                                                 ...      ...  ...
# 7384  https://a0.muscache.com/pictures/4125585/a5d0d...  1775021  ...
# 7385  https://a0.muscache.com/pictures/6856782/0250f...  1837147  ...
# 7386  https://a0.muscache.com/pictures/5920211/54edb...  1775021  ...
# 7387  https://a0.muscache.com/pictures/3e4f5835-dbbc...  1942840  ...
# 7388  https://a0.muscache.com/pictures/8f4042e8-d39f...  1947854  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                           4.98                   4.98                4.91
# 1                           4.72                   4.94                4.09
# 2                           4.97                   4.73                4.79
# 3                           4.81                   4.71                4.70
# 4                           4.96                   4.96                4.86
# ...                          ...                    ...                 ...
# 7384                        4.77                   4.51                4.59
# 7385                        4.92                   4.62                4.74
# 7386                        4.81                   4.62                4.58
# 7387                        4.91                   4.66                4.77
# 7388                        4.96                   4.89                4.82
#
#      license instant_bookable calculated_host_listings_count  \
# 0        NaN                f                              1
# 1        NaN                t                              8
# 2        NaN                f                              1
# 3        NaN                t                              2
# 4        NaN                t                              1
# ...      ...              ...                            ...
# 7384     NaN                f                              4
# 7385     NaN                f                              1
# 7386     NaN                f                              4
# 7387     NaN                f                              3
# 7388     NaN                f                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              1
# 1                                              6
# 2                                              0
# 3                                              2
# 4                                              1
# ...                                          ...
# 7384                                           3
# 7385                                           0
# 7386                                           3
# 7387                                           3
# 7388                                           0
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               0
# 1                                               2
# 2                                               1
# 3                                               0
# 4                                               0
# ...                                           ...
# 7384                                            1
# 7385                                            1
# 7386                                            1
# 7387                                            0
# 7388                                            1
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              3.10
# 1                                              0              0.55
# 2                                              0              2.86
# 3                                              0              2.27
# 4                                              0              1.73
# ...                                          ...               ...
# 7384                                           0              0.33
# 7385                                           0              0.54
# 7386                                           0              0.63
# 7387                                           0              0.74
# 7388                                           0              3.03
#
# [7389 rows x 75 columns]

# %%
columns = ['host_url', 'host_name', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'calendar_updated', 'calendar_last_scraped', 'neighbourhood_group_cleansed']
listings_df.drop(columns=columns, inplace=True)
listings_df
# Out:
#             id                                               name  \
# 0      15420.0                  Georgian Boutique Apt City Centre
# 1     707097.0  Centre Royal Mile Apartment 3 bedrooms 2 bathr...
# 2     728199.0   Private room in central, spacious and comfy flat
# 3     732008.0                          51 18 Caledonian Crescent
# 4     744710.0  Refurbished Flat in a Georgian Era Building in...
# ...        ...                                                ...
# 7384  362653.0                   Papermill Wynd Chiara Apartment,
# 7385  363642.0                 Wonderful/beautiful room Edinburgh
# 7386  376937.0                         Dario Apartment, Edinburgh
# 7387  388297.0  Stunning villa by Holyrood Park -parking & gar...
# 7388  389318.0  City centre. Walk to Castle, Museum etc. Own b...
#
#                                             description  \
# 0     Stunning, spacious ground floor apartment minu...
# 1                                                   NaN
# 2     Fantastic main door flat over two levels withi...
# 3     This beautiful third floor apartment is set in...
# 4     A stunning apartment in the heart of Edinburgh...
# ...                                                 ...
# 7384  <b>The space</b><br />Located just off McDonal...
# 7385  <b>The space</b><br />Room over looking the Pe...
# 7386  <b>The space</b><br />Dario is a new modern ap...
# 7387  On the doorstep of Arthur's Seat and Holyrood ...
# 7388  The Space<br />Situated in a quiet Mews courty...
#
#                                   neighborhood_overview  \
# 0     The neighbourhood is in the historic New Town,...
# 1     The location is the perfect for tourism , shor...
# 2     Great location for access to the city centre, ...
# 3                                                   NaN
# 4     The apartment is in a Central Edinburgh neighb...
# ...                                                 ...
# 7384                                                NaN
# 7385  Close to the city centre.  But surrounded by g...
# 7386                                                NaN
# 7387                                                NaN
# 7388  Southside is a bustling, vibrant, local commun...
#
#                                             picture_url  host_id  host_since  \
# 0     https://a0.muscache.com/pictures/cf69631f-4194...    60423  06/12/2009
# 1     https://a0.muscache.com/pictures/6e2ded8d-f20b...  3092851  29/07/2012
# 2     https://a0.muscache.com/pictures/11315577/0091...  3776412  06/10/2012
# 3     https://a0.muscache.com/pictures/prohost-api/H...  3810279  09/10/2012
# 4     https://a0.muscache.com/pictures/monet/Select-...  3737047  02/10/2012
# ...                                                 ...      ...         ...
# 7384  https://a0.muscache.com/pictures/4125585/a5d0d...  1775021  19/02/2012
# 7385  https://a0.muscache.com/pictures/6856782/0250f...  1837147  01/03/2012
# 7386  https://a0.muscache.com/pictures/5920211/54edb...  1775021  19/02/2012
# 7387  https://a0.muscache.com/pictures/3e4f5835-dbbc...  1942840  17/03/2012
# 7388  https://a0.muscache.com/pictures/8f4042e8-d39f...  1947854  18/03/2012
#
#                   host_location  \
# 0     Edinburgh, United Kingdom
# 1     Edinburgh, United Kingdom
# 2     Edinburgh, United Kingdom
# 3        London, United Kingdom
# 4     Edinburgh, United Kingdom
# ...                         ...
# 7384    Gourock, United Kingdom
# 7385  Edinburgh, United Kingdom
# 7386    Gourock, United Kingdom
# 7387  Edinburgh, United Kingdom
# 7388  Edinburgh, United Kingdom
#
#                                              host_about  host_response_time  \
# 0     I have a background in property, having worked...  within a few hours
# 1     Airbnb partner owner . Will do my best to make...        within a day
# 2     We are an early/mid 40's couple who love to tr...      within an hour
# 3     We are a family run business specialising in h...      within an hour
# 4     I'm Gareth and I own and manage this gem of a ...      within an hour
# ...                                                 ...                 ...
# 7384  I am 56 years old, married with two children, ...  within a few hours
# 7385  I have lived in Edinburgh all my life, and kno...      within an hour
# 7386  I am 56 years old, married with two children, ...  within a few hours
# 7387  Hi… I’m a friendly and sociable female & I liv...      within an hour
# 7388  I live in the city centre and really enjoy thi...                 NaN
#
#       ... review_scores_communication review_scores_location  \
# 0     ...                        4.98                   4.98
# 1     ...                        4.72                   4.94
# 2     ...                        4.97                   4.73
# 3     ...                        4.81                   4.71
# 4     ...                        4.96                   4.96
# ...   ...                         ...                    ...
# 7384  ...                        4.77                   4.51
# 7385  ...                        4.92                   4.62
# 7386  ...                        4.81                   4.62
# 7387  ...                        4.91                   4.66
# 7388  ...                        4.96                   4.89
#
#      review_scores_value license instant_bookable  \
# 0                   4.91     NaN                f
# 1                   4.09     NaN                t
# 2                   4.79     NaN                f
# 3                   4.70     NaN                t
# 4                   4.86     NaN                t
# ...                  ...     ...              ...
# 7384                4.59     NaN                f
# 7385                4.74     NaN                f
# 7386                4.58     NaN                f
# 7387                4.77     NaN                f
# 7388                4.82     NaN                f
#
#      calculated_host_listings_count  \
# 0                                 1
# 1                                 8
# 2                                 1
# 3                                 2
# 4                                 1
# ...                             ...
# 7384                              4
# 7385                              1
# 7386                              4
# 7387                              3
# 7388                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               6
# 2                                               0
# 3                                               2
# 4                                               1
# ...                                           ...
# 7384                                            3
# 7385                                            0
# 7386                                            3
# 7387                                            3
# 7388                                            0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                2
# 2                                                1
# 3                                                0
# 4                                                0
# ...                                            ...
# 7384                                             1
# 7385                                             1
# 7386                                             1
# 7387                                             0
# 7388                                             1
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              3.10
# 1                                              0              0.55
# 2                                              0              2.86
# 3                                              0              2.27
# 4                                              0              1.73
# ...                                          ...               ...
# 7384                                           0              0.33
# 7385                                           0              0.54
# 7386                                           0              0.63
# 7387                                           0              0.74
# 7388                                           0              3.03
#
# [7389 rows x 66 columns]

# %%
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7389 entries, 0 to 7388
# Data columns (total 66 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7389 non-null   float64
#  1   name                                          7389 non-null   object
#  2   description                                   7318 non-null   object
#  3   neighborhood_overview                         5184 non-null   object
#  4   picture_url                                   7389 non-null   object
#  5   host_id                                       7389 non-null   int64
#  6   host_since                                    7389 non-null   object
#  7   host_location                                 6067 non-null   object
#  8   host_about                                    4292 non-null   object
#  9   host_response_time                            5861 non-null   object
#  10  host_response_rate                            5861 non-null   object
#  11  host_acceptance_rate                          6663 non-null   object
#  12  host_is_superhost                             7387 non-null   object
#  13  host_thumbnail_url                            7389 non-null   object
#  14  host_picture_url                              7389 non-null   object
#  15  host_neighbourhood                            3007 non-null   object
#  16  host_listings_count                           7389 non-null   int64
#  17  host_total_listings_count                     7389 non-null   int64
#  18  host_verifications                            7389 non-null   object
#  19  host_has_profile_pic                          7389 non-null   object
#  20  host_identity_verified                        7389 non-null   object
#  21  neighbourhood                                 5184 non-null   object
#  22  neighbourhood_cleansed                        7389 non-null   object
#  23  latitude                                      7389 non-null   float64
#  24  longitude                                     7389 non-null   float64
#  25  property_type                                 7389 non-null   object
#  26  room_type                                     7389 non-null   object
#  27  accommodates                                  7389 non-null   int64
#  28  bathrooms                                     0 non-null      float64
#  29  bathrooms_text                                7376 non-null   object
#  30  bedrooms                                      7251 non-null   float64
#  31  beds                                          7284 non-null   float64
#  32  amenities                                     7389 non-null   object
#  33  price                                         7389 non-null   object
#  34  minimum_nights                                7389 non-null   int64
#  35  maximum_nights                                7389 non-null   int64
#  36  minimum_minimum_nights                        7389 non-null   int64
#  37  maximum_minimum_nights                        7389 non-null   int64
#  38  minimum_maximum_nights                        7389 non-null   int64
#  39  maximum_maximum_nights                        7389 non-null   int64
#  40  minimum_nights_avg_ntm                        7389 non-null   float64
#  41  maximum_nights_avg_ntm                        7389 non-null   float64
#  42  has_availability                              7389 non-null   object
#  43  availability_30                               7389 non-null   int64
#  44  availability_60                               7389 non-null   int64
#  45  availability_90                               7389 non-null   int64
#  46  availability_365                              7389 non-null   int64
#  47  number_of_reviews                             7389 non-null   int64
#  48  number_of_reviews_ltm                         7389 non-null   int64
#  49  number_of_reviews_l30d                        7389 non-null   int64
#  50  first_review                                  6724 non-null   object
#  51  last_review                                   6724 non-null   object
#  52  review_scores_rating                          6724 non-null   float64
#  53  review_scores_accuracy                        6711 non-null   float64
#  54  review_scores_cleanliness                     6711 non-null   float64
#  55  review_scores_checkin                         6711 non-null   float64
#  56  review_scores_communication                   6711 non-null   float64
#  57  review_scores_location                        6711 non-null   float64
#  58  review_scores_value                           6711 non-null   float64
#  59  license                                       15 non-null     object
#  60  instant_bookable                              7389 non-null   object
#  61  calculated_host_listings_count                7389 non-null   int64
#  62  calculated_host_listings_count_entire_homes   7389 non-null   int64
#  63  calculated_host_listings_count_private_rooms  7389 non-null   int64
#  64  calculated_host_listings_count_shared_rooms   7389 non-null   int64
#  65  reviews_per_month                             6724 non-null   float64
# dtypes: float64(16), int64(21), object(29)
# memory usage: 3.7+ MB
