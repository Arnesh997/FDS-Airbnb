# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
listings_filepath = '/Users/arneshsaha/Desktop/AirBnb/datasets/listings.csv'
listings_df = pd.read_csv(listings_filepath)
listings_df.head(5)
# Out:
#          id                          listing_url     scrape_id last_scraped  \
# 0   15420.0   https://www.airbnb.com/rooms/15420  2.022120e+13   16/12/2022
# 1  707097.0  https://www.airbnb.com/rooms/707097  2.022120e+13   16/12/2022
# 2  728199.0  https://www.airbnb.com/rooms/728199  2.022120e+13   16/12/2022
# 3  732008.0  https://www.airbnb.com/rooms/732008  2.022120e+13   16/12/2022
# 4  744710.0  https://www.airbnb.com/rooms/744710  2.022120e+13   16/12/2022
#
#         source                                               name  \
# 0  city scrape                  Georgian Boutique Apt City Centre
# 1  city scrape  Centre Royal Mile Apartment 3 bedrooms 2 bathr...
# 2  city scrape   Private room in central, spacious and comfy flat
# 3  city scrape                          51 18 Caledonian Crescent
# 4  city scrape  Refurbished Flat in a Georgian Era Building in...
#
#                                          description  \
# 0  Stunning, spacious ground floor apartment minu...
# ...

# %% [markdown]
# Data Cleaning

# %% [markdown]
# 1. neighbourhood_group_cleansed (Check if the whole column is empty)

# %%
columns = ['host_url', 'host_name', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'calendar_updated', 'calendar_last_scraped','picture_url', 'neighbourhood_group_cleansed','license']
listings_df.drop(columns=columns, inplace=True)
listings_df.head(5)
# Out:
#          id                                               name  \
# 0   15420.0                  Georgian Boutique Apt City Centre
# 1  707097.0  Centre Royal Mile Apartment 3 bedrooms 2 bathr...
# 2  728199.0   Private room in central, spacious and comfy flat
# 3  732008.0                          51 18 Caledonian Crescent
# 4  744710.0  Refurbished Flat in a Georgian Era Building in...
#
#                                          description  \
# 0  Stunning, spacious ground floor apartment minu...
# 1                                                NaN
# 2  Fantastic main door flat over two levels withi...
# 3  This beautiful third floor apartment is set in...
# 4  A stunning apartment in the heart of Edinburgh...
#
#                                neighborhood_overview  host_id  host_since  \
# 0  The neighbourhood is in the historic New Town,...    60423  06/12/2009
# 1  The location is the perfect for tourism , shor...  3092851  29/07/2012
# ...

# %%
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7389 entries, 0 to 7388
# Data columns (total 64 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7389 non-null   float64
#  1   name                                          7389 non-null   object
#  2   description                                   7318 non-null   object
#  3   neighborhood_overview                         5184 non-null   object
#  4   host_id                                       7389 non-null   int64
#  5   host_since                                    7389 non-null   object
#  6   host_location                                 6067 non-null   object
#  7   host_about                                    4292 non-null   object
#  8   host_response_time                            5861 non-null   object
# ...

# %% [markdown]
# Modification
# <p>8. Removing the HTML Tags from description</p>

# %%
from bs4 import BeautifulSoup
# define a function to remove HTML tags from a string
def remove_html_tags(text):
    if pd.isna(text):
        return text
    soup = BeautifulSoup(text, 'html.parser')
    return soup.get_text()

# apply the function to the "description" column
listings_df['description'] = listings_df['description'].apply(remove_html_tags)

# print the updated dataframe
listings_df['description']
# Out:
# /var/folders/rv/l0bvb2qx7kj9z133h3zxt1040000gn/T/ipykernel_12774/3168537498.py:6: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(text, 'html.parser')
# 0       Stunning, spacious ground floor apartment minu...
# 1                                                     NaN
# 2       Fantastic main door flat over two levels withi...
# 3       This beautiful third floor apartment is set in...
# 4       A stunning apartment in the heart of Edinburgh...
#                               ...
# 7384    The spaceLocated just off McDonald Road, Paper...
# 7385    The spaceRoom over looking the Pentland Hill  ...
# 7386    The spaceDario is a new modern apartment minut...
# 7387    On the doorstep of Arthur's Seat and Holyrood ...
# 7388    The SpaceSituated in a quiet Mews courtyard, t...
# Name: description, Length: 7389, dtype: object

# %% [markdown]
# <p>7. Seperate parking from description/name</p>

# %%
parking_rows = listings_df[(listings_df['name'].str.contains('parking', case=False)) | 
                           (listings_df['amenities'].apply(lambda x: 'parking' in x))]
parking_rows
# Out:
#             id                                               name  \
# 0      15420.0                  Georgian Boutique Apt City Centre
# 1     707097.0  Centre Royal Mile Apartment 3 bedrooms 2 bathr...
# 2     728199.0   Private room in central, spacious and comfy flat
# 3     732008.0                          51 18 Caledonian Crescent
# 4     744710.0  Refurbished Flat in a Georgian Era Building in...
# ...        ...                                                ...
# 7383  361050.0  Large room in disabled friendly flat - Bruntsf...
# 7384  362653.0                   Papermill Wynd Chiara Apartment,
# 7385  363642.0                 Wonderful/beautiful room Edinburgh
# 7386  376937.0                         Dario Apartment, Edinburgh
# 7387  388297.0  Stunning villa by Holyrood Park -parking & gar...
#
#                                             description  \
# 0     Stunning, spacious ground floor apartment minu...
# 1                                                   NaN
# ...

# %% [markdown]
# Creating a new column in dataframe, 'Parking', containing 0/1 based on whether the property has Parking space for the customer

# %%
listings_df['Parking'] = 0
listings_df.loc[parking_rows.index, 'Parking'] = 1

# %% [markdown]
# <p>6. Finding unique values in room_type
# </p>

# %%
room_type_counts = listings_df['room_type'].value_counts()
room_type_counts
# Out:
# Entire home/apt    5172
# Private room       2170
# Hotel room           32
# Shared room          15
# Name: room_type, dtype: int64

# %%
room_type_labels, room_type_unique = pd.factorize(listings_df['room_type'])

# replace the property type text with the assigned labels
listings_df['room_type_num'] = room_type_labels
print(room_type_labels)
print(room_type_unique)
listings_df.to_csv('/Users/arneshsaha/Desktop/AirBnb/datasets/cleaned.csv')
# Out:
# [0 0 1 ... 0 0 1]
# Index(['Entire home/apt', 'Private room', 'Shared room', 'Hotel room'], dtype='object')

# %% [markdown]
# <p>5. Finding unique values in property_type
# </p>

# %%
property_type_counts = listings_df['property_type'].value_counts()
property_type_counts
# Out:
# Entire rental unit                    3078
# Entire condo                          1358
# Private room in rental unit            784
# Private room in condo                  582
# Entire home                            307
# Private room in home                   299
# Private room in townhouse              147
# Entire serviced apartment              127
# Entire townhouse                        83
# Private room in bed and breakfast       83
# Room in boutique hotel                  75
# Room in hotel                           48
# Private room in guesthouse              41
# Entire guest suite                      37
# Entire cottage                          36
# Private room in bungalow                28
# Entire vacation home                    26
# Room in hostel                          22
# Private room in casa particular         20
# Room in aparthotel                      20
# Entire loft                             20
# Private room in hostel                  19
# ...

# %% [markdown]
# <p>From the value_count, my observations:
#     <ol>
#         <li>I notice that there are 3 places which have been listed under the property_type 'Entire Place' which is very similar to 'Entire Rental Unit'. I think we should merge '..Place' into '...Unit'. This will help us deal with outliers</li> <br>
#         <li>At the end of the list I notice that there are certain places, which are very unique like 'Windmill', 'Barn', etc. which just have only 1-3 propeerties listed under them. We can either delete these properties (For outliers), or we could also determine if having an unique property helps in gaining more 'ratings', 'earnings', etc. </li>
#     </ol>
# </p>

# %% [markdown]
# <p>4. Remove % symbols
#         <ul>
#             <li>host_acceptance_rate</li>
#             <li>host_response_rate</li>
#         </ul>
# <p>

# %%
listings_df['host_acceptance_rate'] = listings_df['host_acceptance_rate'].str.replace('%', '')
listings_df['host_response_rate'] = listings_df['host_response_rate'].str.replace('%', '')
listings_df
