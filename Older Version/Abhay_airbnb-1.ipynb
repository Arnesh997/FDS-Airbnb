# %%
import numpy as np
import pandas as pd
import os 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
listings_filepath = '/Users/abhayrakeshdeshmukhmaurya/Library/CloudStorage/OneDrive-UniversityofEdinburgh/CS/University/Year 2/Data Science/CW3/AirBnb/datasets/listings.csv'
listings_df = pd.read_csv(listings_filepath)

# %%
# Deleting Columns
columns = ['host_url', 'host_name', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'calendar_updated', 'calendar_last_scraped','picture_url', 'neighbourhood_group_cleansed','license']
listings_df.drop(columns=columns, inplace=True)
listings_df.head(5)
# Out:
#        id                                               name  \
# 0   15420                  Georgian Boutique Apt City Centre
# 1  707097  Centre Royal Mile Apartment 3 bedrooms 2 bathr...
# 2  728199   Private room in central, spacious and comfy flat
# 3  732008                          51 18 Caledonian Crescent
# 4  744710  Refurbished Flat in a Georgian Era Building in...
#
#                                          description  \
# 0  Stunning, spacious ground floor apartment minu...
# 1                                                NaN
# 2  Fantastic main door flat over two levels withi...
# 3  This beautiful third floor apartment is set in...
# 4  A stunning apartment in the heart of Edinburgh...
#
#                                neighborhood_overview  host_id  host_since  \
# 0  The neighbourhood is in the historic New Town,...    60423  2009-12-06
# 1  The location is the perfect for tourism , shor...  3092851  2012-07-29
# 2  Great location for access to the city centre, ...  3776412  2012-10-06
# 3                                                NaN  3810279  2012-10-09
# 4  The apartment is in a Central Edinburgh neighb...  3737047  2012-10-02
#
#                host_location  \
# 0  Edinburgh, United Kingdom
# 1  Edinburgh, United Kingdom
# 2  Edinburgh, United Kingdom
# 3     London, United Kingdom
# 4  Edinburgh, United Kingdom
#
#                                           host_about  host_response_time  \
# 0  I have a background in property, having worked...  within a few hours
# 1  Airbnb partner owner . Will do my best to make...        within a day
# 2  We are an early/mid 40's couple who love to tr...      within an hour
# 3  We are a family run business specialising in h...      within an hour
# 4  I'm Gareth and I own and manage this gem of a ...      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  96%                 t
# 1                50%                  84%                 f
# 2               100%                  95%                 t
# 3               100%                  99%                 f
# 4               100%                 100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/60423/profile...
# 1  https://a0.muscache.com/im/pictures/user/7a078...
# 2  https://a0.muscache.com/im/pictures/user/5e480...
# 3  https://a0.muscache.com/im/pictures/user/47dd0...
# 4  https://a0.muscache.com/im/pictures/user/10e2c...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/60423/profile...                NaN
# 1  https://a0.muscache.com/im/pictures/user/7a078...           Old Town
# 2  https://a0.muscache.com/im/pictures/user/5e480...                NaN
# 3  https://a0.muscache.com/im/pictures/user/47dd0...          Haymarket
# 4  https://a0.muscache.com/im/pictures/user/10e2c...           New Town
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                    3                          6  ['email', 'phone']
# 1                    9                         16  ['email', 'phone']
# 2                    1                          2  ['email', 'phone']
# 3                    6                          9  ['email', 'phone']
# 4                    1                          1  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      t
# 3                    t                      t
# 4                    t                      t
#
#                                   neighbourhood  \
# 0  Edinburgh, City of Edinburgh, United Kingdom
# 1                     Edinburgh, United Kingdom
# 2                     Edinburgh, United Kingdom
# 3                                           NaN
# 4           Edinburgh, Scotland, United Kingdom
#
#                       neighbourhood_cleansed  latitude  longitude  \
# 0  Old Town, Princes Street and Leith Street  55.95759   -3.18805
# 1  Old Town, Princes Street and Leith Street  55.94980   -3.18354
# 2                                   Polwarth  55.93692   -3.22414
# 3                   Dalry and Fountainbridge  55.94192   -3.21878
# 4                              Deans Village  55.95324   -3.20368
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0           Entire rental unit  Entire home/apt             2        NaN
# 1                 Entire condo  Entire home/apt             9        NaN
# 2  Private room in rental unit     Private room             3        NaN
# 3           Entire rental unit  Entire home/apt            10        NaN
# 4           Entire rental unit  Entire home/apt             4        NaN
#
#    bathrooms_text  bedrooms  beds  \
# 0          1 bath       1.0   1.0
# 1         2 baths       3.0   7.0
# 2  1 private bath       1.0   1.0
# 3         2 baths       4.0   8.0
# 4          1 bath       2.0   2.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Self check-in", "Hot water kettle", "Private...  $114.00               3
# 1  ["TV with standard cable", "Stove", "Self chec...  $598.00               2
# 2  ["Self check-in", "Stove", "Bed linens", "Chil...   $60.00               1
# 3  ["Free parking on premises \u2013 1 space", "S...  $162.00               2
# 4  ["Bathroom essentials", "Self check-in", "Carb...  $138.00               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              30                       1                       3
# 1            1000                      28                     300
# 2              14                       1                       4
# 3            1125                       2                       5
# 4              30                       2                       4
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                      30                      30                     3.0
# 1                    1125                    1125                   104.3
# 2                      14                      14                     1.3
# 3                      20                      30                     2.3
# 4                      30                      30                     2.0
#
#    maximum_nights_avg_ntm has_availability  availability_30  availability_60  \
# 0                    30.0                t                5               22
# 1                  1125.0                t                0                4
# 2                    14.0                t                6               24
# 3                    29.9                t                4               14
# 4                    30.0                t                3               21
#
#    availability_90  availability_365  number_of_reviews  \
# 0               35               187                450
# 1                4               210                 67
# 2               49               195                354
# 3               31               159                268
# 4               27                84                210
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                     73                       4   2011-01-18  2022-11-29
# 1                      7                       0   2013-01-03  2022-09-22
# 2                     52                       2   2012-10-22  2022-12-04
# 3                     51                       4   2013-03-30  2022-12-04
# 4                      7                       0   2012-12-29  2022-09-20
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.97                    4.98                       4.96
# 1                  4.38                    4.32                       4.40
# 2                  4.82                    4.86                       4.81
# 3                  4.74                    4.81                       4.80
# 4                  4.96                    4.95                       4.96
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.97                         4.98                    4.98
# 1                   4.69                         4.72                    4.94
# 2                   4.95                         4.97                    4.73
# 3                   4.84                         4.81                    4.71
# 4                   4.93                         4.96                    4.96
#
#    review_scores_value instant_bookable  calculated_host_listings_count  \
# 0                 4.91                f                               1
# 1                 4.09                t                               8
# 2                 4.79                f                               1
# 3                 4.70                t                               2
# 4                 4.86                t                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            6
# 2                                            0
# 3                                            2
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             2
# 2                                             1
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               3.10
# 1                                            0               0.55
# 2                                            0               2.86
# 3                                            0               2.27
# 4                                            0               1.73

# %%
# Converting True, False to 1, 0
replace_dict = {'instant_bookable':{'t':1, 'f':0}, 
                'host_identity_verified':{'t':1, 'f':0},
                'host_has_profile_pic':{'t':1, 'f':0},
                'host_is_superhost':{'t':1, 'f':0},
                'has_availability':{'t':1, 'f':0}
                }
listings_df = listings_df.replace(replace_dict)

# %%
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7389 entries, 0 to 7388
# Data columns (total 64 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7389 non-null   int64
#  1   name                                          7389 non-null   object
#  2   description                                   7318 non-null   object
#  3   neighborhood_overview                         5184 non-null   object
#  4   host_id                                       7389 non-null   int64
#  5   host_since                                    7389 non-null   object
#  6   host_location                                 6067 non-null   object
#  7   host_about                                    4292 non-null   object
#  8   host_response_time                            5861 non-null   object
#  9   host_response_rate                            5861 non-null   object
#  10  host_acceptance_rate                          6663 non-null   object
#  11  host_is_superhost                             7387 non-null   float64
#  12  host_thumbnail_url                            7389 non-null   object
#  13  host_picture_url                              7389 non-null   object
#  14  host_neighbourhood                            3007 non-null   object
#  15  host_listings_count                           7389 non-null   int64
#  16  host_total_listings_count                     7389 non-null   int64
#  17  host_verifications                            7389 non-null   object
#  18  host_has_profile_pic                          7389 non-null   int64
#  19  host_identity_verified                        7389 non-null   int64
#  20  neighbourhood                                 5184 non-null   object
#  21  neighbourhood_cleansed                        7389 non-null   object
#  22  latitude                                      7389 non-null   float64
#  23  longitude                                     7389 non-null   float64
#  24  property_type                                 7389 non-null   object
#  25  room_type                                     7389 non-null   object
#  26  accommodates                                  7389 non-null   int64
#  27  bathrooms                                     0 non-null      float64
#  28  bathrooms_text                                7376 non-null   object
#  29  bedrooms                                      7251 non-null   float64
#  30  beds                                          7284 non-null   float64
#  31  amenities                                     7389 non-null   object
#  32  price                                         7389 non-null   object
#  33  minimum_nights                                7389 non-null   int64
#  34  maximum_nights                                7389 non-null   int64
#  35  minimum_minimum_nights                        7389 non-null   int64
#  36  maximum_minimum_nights                        7389 non-null   int64
#  37  minimum_maximum_nights                        7389 non-null   int64
#  38  maximum_maximum_nights                        7389 non-null   int64
#  39  minimum_nights_avg_ntm                        7389 non-null   float64
#  40  maximum_nights_avg_ntm                        7389 non-null   float64
#  41  has_availability                              7389 non-null   int64
#  42  availability_30                               7389 non-null   int64
#  43  availability_60                               7389 non-null   int64
#  44  availability_90                               7389 non-null   int64
#  45  availability_365                              7389 non-null   int64
#  46  number_of_reviews                             7389 non-null   int64
#  47  number_of_reviews_ltm                         7389 non-null   int64
#  48  number_of_reviews_l30d                        7389 non-null   int64
#  49  first_review                                  6724 non-null   object
#  50  last_review                                   6724 non-null   object
#  51  review_scores_rating                          6724 non-null   float64
#  52  review_scores_accuracy                        6711 non-null   float64
#  53  review_scores_cleanliness                     6711 non-null   float64
#  54  review_scores_checkin                         6711 non-null   float64
#  55  review_scores_communication                   6711 non-null   float64
#  56  review_scores_location                        6711 non-null   float64
#  57  review_scores_value                           6711 non-null   float64
#  58  instant_bookable                              7389 non-null   int64
#  59  calculated_host_listings_count                7389 non-null   int64
#  60  calculated_host_listings_count_entire_homes   7389 non-null   int64
#  61  calculated_host_listings_count_private_rooms  7389 non-null   int64
#  62  calculated_host_listings_count_shared_rooms   7389 non-null   int64
#  63  reviews_per_month                             6724 non-null   float64
# dtypes: float64(16), int64(26), object(22)
# memory usage: 3.6+ MB

# %%
listings_df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7389 entries, 0 to 7388
# Data columns (total 64 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7389 non-null   int64
#  1   name                                          7389 non-null   object
#  2   description                                   7318 non-null   object
#  3   neighborhood_overview                         5184 non-null   object
#  4   host_id                                       7389 non-null   int64
#  5   host_since                                    7389 non-null   object
#  6   host_location                                 6067 non-null   object
#  7   host_about                                    4292 non-null   object
#  8   host_response_time                            5861 non-null   object
#  9   host_response_rate                            5861 non-null   object
#  10  host_acceptance_rate                          6663 non-null   object
#  11  host_is_superhost                             7387 non-null   object
#  12  host_thumbnail_url                            7389 non-null   object
#  13  host_picture_url                              7389 non-null   object
#  14  host_neighbourhood                            3007 non-null   object
#  15  host_listings_count                           7389 non-null   int64
#  16  host_total_listings_count                     7389 non-null   int64
#  17  host_verifications                            7389 non-null   object
#  18  host_has_profile_pic                          7389 non-null   object
#  19  host_identity_verified                        7389 non-null   object
#  20  neighbourhood                                 5184 non-null   object
#  21  neighbourhood_cleansed                        7389 non-null   object
#  22  latitude                                      7389 non-null   float64
#  23  longitude                                     7389 non-null   float64
#  24  property_type                                 7389 non-null   object
#  25  room_type                                     7389 non-null   object
#  26  accommodates                                  7389 non-null   int64
#  27  bathrooms                                     0 non-null      float64
#  28  bathrooms_text                                7376 non-null   object
#  29  bedrooms                                      7251 non-null   float64
#  30  beds                                          7284 non-null   float64
#  31  amenities                                     7389 non-null   object
#  32  price                                         7389 non-null   object
#  33  minimum_nights                                7389 non-null   int64
#  34  maximum_nights                                7389 non-null   int64
#  35  minimum_minimum_nights                        7389 non-null   int64
#  36  maximum_minimum_nights                        7389 non-null   int64
#  37  minimum_maximum_nights                        7389 non-null   int64
#  38  maximum_maximum_nights                        7389 non-null   int64
#  39  minimum_nights_avg_ntm                        7389 non-null   float64
#  40  maximum_nights_avg_ntm                        7389 non-null   float64
#  41  has_availability                              7389 non-null   object
#  42  availability_30                               7389 non-null   int64
#  43  availability_60                               7389 non-null   int64
#  44  availability_90                               7389 non-null   int64
#  45  availability_365                              7389 non-null   int64
#  46  number_of_reviews                             7389 non-null   int64
#  47  number_of_reviews_ltm                         7389 non-null   int64
#  48  number_of_reviews_l30d                        7389 non-null   int64
#  49  first_review                                  6724 non-null   object
#  50  last_review                                   6724 non-null   object
#  51  review_scores_rating                          6724 non-null   float64
#  52  review_scores_accuracy                        6711 non-null   float64
#  53  review_scores_cleanliness                     6711 non-null   float64
#  54  review_scores_checkin                         6711 non-null   float64
#  55  review_scores_communication                   6711 non-null   float64
#  56  review_scores_location                        6711 non-null   float64
#  57  review_scores_value                           6711 non-null   float64
#  58  instant_bookable                              7389 non-null   int64
#  59  calculated_host_listings_count                7389 non-null   int64
#  60  calculated_host_listings_count_entire_homes   7389 non-null   int64
#  61  calculated_host_listings_count_private_rooms  7389 non-null   int64
#  62  calculated_host_listings_count_shared_rooms   7389 non-null   int64
#  63  reviews_per_month                             6724 non-null   float64
# dtypes: float64(15), int64(23), object(26)
# memory usage: 3.6+ MB

# %%
with_license = listings_df[listings_df['license'].notnull()]
with_license
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/FDS/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/opt/anaconda3/envs/FDS/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/FDS/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'license'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 with_license = listings_df[listings_df['license'].notnull()]
#       2 with_license
#
# File ~/opt/anaconda3/envs/FDS/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/FDS/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'license'
